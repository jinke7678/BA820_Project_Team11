# %% [markdown]
# ### Datasets clean

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from datetime import datetime
import seaborn as sns
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df_reviews = pd.read_csv('/content/drive/MyDrive/BA820-UsML-Team11/Dataset/reviews.csv')
df_reviews.drop(['id','reviewer_name'], axis=1, inplace=True)
df_reviews.rename(columns={'date': 'review_date'}, inplace=True)
df_reviews
# Out:
#                  listing_id review_date  reviewer_id  \
# 0                      3781  2015-07-10     36059247
# 1                      3781  2015-08-09     10459388
# 2                      3781  2015-09-01     12264652
# 3                      3781  2015-09-30     41426327
# 4                      3781  2015-10-30     15151513
# ...                     ...         ...          ...
# 182477  1039150219616773193  2023-12-13    381198215
# 182478  1040527526059629043  2023-12-08      9723289
# 182479  1040634799097914803  2023-12-15    494876133
# 182480  1040634799097914803  2023-12-18     94199776
# 182481  1046563598019556549  2023-12-16    336213171
#
#                                                  comments
# 0       The apartment was as advertised and Frank was ...
# 1       It was a pleasure to stay at Frank's place. Th...
# 2       The apartment description is entirely faithful...
# 3       Thoroughly enjoyed my time at Frank's home. Ha...
# 4       Great value for the money! This location has e...
# ...                                                   ...
# 182477  A wonderful location to walk around the North ...
# 182478                   Great deal and responsive hosts!
# 182479  Our stay at Diego’s place was great!<br/>The a...
# 182480  Good place; solid bedrooms/bathrooms; nice to ...
# 182481          Great host great home and amazing service
#
# [182482 rows x 4 columns]

# %%
df_list= pd.read_csv('/content/drive/MyDrive/BA820-UsML-Team11/Dataset/listings.csv')

# %%
columns_to_keep= [
    'id','neighbourhood_cleansed','price', 'latitude', 'longitude',
    'room_type', 'number_of_reviews','review_scores_rating']
df_list1= df_list[columns_to_keep]
df_list1 = df_list1.drop_duplicates()
df_list1.rename(columns={'id': 'listing_id'}, inplace=True)
df_list1
# Out:
#                listing_id neighbourhood_cleansed    price   latitude  \
# 0                    3781            East Boston  $125.00  42.364130
# 1                    5506                Roxbury  $135.00  42.328440
# 2                    6695                Roxbury  $179.00  42.328020
# 3                    8789            Beacon Hill   $91.00  42.358670
# 4                   10813               Back Bay   $86.00  42.350610
# ...                   ...                    ...      ...        ...
# 4199  1046563598019556549             Dorchester   $83.00  42.285236
# 4200  1046568292864752336               Downtown  $107.00  42.352970
# 4201  1047166785349446101                 Fenway  $136.00  42.347480
# 4202  1047226383263246733             Dorchester   $83.00  42.285161
# 4203  1048051750111422883                Roxbury  $106.00  42.326623
#
#       longitude        room_type  number_of_reviews  review_scores_rating
# 0    -71.029910  Entire home/apt                 24                  4.96
# 1    -71.095810  Entire home/apt                122                  4.79
# 2    -71.093870  Entire home/apt                127                  4.81
# 3    -71.063070  Entire home/apt                 27                  4.67
# 4    -71.087870  Entire home/apt                  5                  5.00
# ...         ...              ...                ...                   ...
# 4199 -71.069907  Entire home/apt                  1                  5.00
# 4200 -71.063690  Entire home/apt                  0                   NaN
# 4201 -71.090780  Entire home/apt                  0                   NaN
# 4202 -71.067922  Entire home/apt                  0                   NaN
# 4203 -71.071826  Entire home/apt                  0                   NaN
#
# [4204 rows x 8 columns]

# %%
df = pd.merge(df_reviews, df_list1, on='listing_id', how='left')
df
# Out:
#                  listing_id review_date  reviewer_id  \
# 0                      3781  2015-07-10     36059247
# 1                      3781  2015-08-09     10459388
# 2                      3781  2015-09-01     12264652
# 3                      3781  2015-09-30     41426327
# 4                      3781  2015-10-30     15151513
# ...                     ...         ...          ...
# 182477  1039150219616773193  2023-12-13    381198215
# 182478  1040527526059629043  2023-12-08      9723289
# 182479  1040634799097914803  2023-12-15    494876133
# 182480  1040634799097914803  2023-12-18     94199776
# 182481  1046563598019556549  2023-12-16    336213171
#
#                                                  comments  \
# 0       The apartment was as advertised and Frank was ...
# 1       It was a pleasure to stay at Frank's place. Th...
# 2       The apartment description is entirely faithful...
# 3       Thoroughly enjoyed my time at Frank's home. Ha...
# 4       Great value for the money! This location has e...
# ...                                                   ...
# 182477  A wonderful location to walk around the North ...
# 182478                   Great deal and responsive hosts!
# 182479  Our stay at Diego’s place was great!<br/>The a...
# 182480  Good place; solid bedrooms/bathrooms; nice to ...
# 182481          Great host great home and amazing service
#
#        neighbourhood_cleansed    price   latitude  longitude        room_type  \
# 0                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# 1                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# 2                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# 3                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# 4                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# ...                       ...      ...        ...        ...              ...
# 182477              North End  $110.00  42.365322 -71.055627  Entire home/apt
# 182478            East Boston  $140.00  42.381106 -71.026179  Entire home/apt
# 182479                Roxbury  $144.00  42.325558 -71.073339  Entire home/apt
# 182480                Roxbury  $144.00  42.325558 -71.073339  Entire home/apt
# 182481             Dorchester   $83.00  42.285236 -71.069907  Entire home/apt
#
#         number_of_reviews  review_scores_rating
# 0                      24                  4.96
# 1                      24                  4.96
# 2                      24                  4.96
# 3                      24                  4.96
# 4                      24                  4.96
# ...                   ...                   ...
# 182477                  1                  5.00
# 182478                  1                  5.00
# 182479                  2                  4.50
# 182480                  2                  4.50
# 182481                  1                  5.00
#
# [182482 rows x 11 columns]

# %%
df.isna().sum()
# Out:
# listing_id                   0
# review_date                  0
# reviewer_id                  0
# comments                    52
# neighbourhood_cleansed       0
# price                     7901
# latitude                     0
# longitude                    0
# room_type                    0
# number_of_reviews            0
# review_scores_rating         0
# dtype: int64

# %%
data = df.dropna(subset=['comments'])
data
# Out:
#                  listing_id review_date  reviewer_id  \
# 0                      3781  2015-07-10     36059247
# 1                      3781  2015-08-09     10459388
# 2                      3781  2015-09-01     12264652
# 3                      3781  2015-09-30     41426327
# 4                      3781  2015-10-30     15151513
# ...                     ...         ...          ...
# 182477  1039150219616773193  2023-12-13    381198215
# 182478  1040527526059629043  2023-12-08      9723289
# 182479  1040634799097914803  2023-12-15    494876133
# 182480  1040634799097914803  2023-12-18     94199776
# 182481  1046563598019556549  2023-12-16    336213171
#
#                                                  comments  \
# 0       The apartment was as advertised and Frank was ...
# 1       It was a pleasure to stay at Frank's place. Th...
# 2       The apartment description is entirely faithful...
# 3       Thoroughly enjoyed my time at Frank's home. Ha...
# 4       Great value for the money! This location has e...
# ...                                                   ...
# 182477  A wonderful location to walk around the North ...
# 182478                   Great deal and responsive hosts!
# 182479  Our stay at Diego’s place was great!<br/>The a...
# 182480  Good place; solid bedrooms/bathrooms; nice to ...
# 182481          Great host great home and amazing service
#
#        neighbourhood_cleansed    price   latitude  longitude        room_type  \
# 0                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# 1                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# 2                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# 3                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# 4                 East Boston  $125.00  42.364130 -71.029910  Entire home/apt
# ...                       ...      ...        ...        ...              ...
# 182477              North End  $110.00  42.365322 -71.055627  Entire home/apt
# 182478            East Boston  $140.00  42.381106 -71.026179  Entire home/apt
# 182479                Roxbury  $144.00  42.325558 -71.073339  Entire home/apt
# 182480                Roxbury  $144.00  42.325558 -71.073339  Entire home/apt
# 182481             Dorchester   $83.00  42.285236 -71.069907  Entire home/apt
#
#         number_of_reviews  review_scores_rating
# 0                      24                  4.96
# 1                      24                  4.96
# 2                      24                  4.96
# 3                      24                  4.96
# 4                      24                  4.96
# ...                   ...                   ...
# 182477                  1                  5.00
# 182478                  1                  5.00
# 182479                  2                  4.50
# 182480                  2                  4.50
# 182481                  1                  5.00
#
# [182430 rows x 11 columns]

# %%
data['price'] = data['price'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
price_means = data.groupby(['room_type'])['price'].transform('mean')
data['price'] = data['price'].fillna(price_means)

# %%
data
# Out:
#                  listing_id review_date  reviewer_id  \
# 0                      3781  2015-07-10     36059247
# 1                      3781  2015-08-09     10459388
# 2                      3781  2015-09-01     12264652
# 3                      3781  2015-09-30     41426327
# 4                      3781  2015-10-30     15151513
# ...                     ...         ...          ...
# 182477  1039150219616773193  2023-12-13    381198215
# 182478  1040527526059629043  2023-12-08      9723289
# 182479  1040634799097914803  2023-12-15    494876133
# 182480  1040634799097914803  2023-12-18     94199776
# 182481  1046563598019556549  2023-12-16    336213171
#
#                                                  comments  \
# 0       The apartment was as advertised and Frank was ...
# 1       It was a pleasure to stay at Frank's place. Th...
# 2       The apartment description is entirely faithful...
# 3       Thoroughly enjoyed my time at Frank's home. Ha...
# 4       Great value for the money! This location has e...
# ...                                                   ...
# 182477  A wonderful location to walk around the North ...
# 182478                   Great deal and responsive hosts!
# 182479  Our stay at Diego’s place was great!<br/>The a...
# 182480  Good place; solid bedrooms/bathrooms; nice to ...
# 182481          Great host great home and amazing service
#
#        neighbourhood_cleansed  price   latitude  longitude        room_type  \
# 0                 East Boston  125.0  42.364130 -71.029910  Entire home/apt
# 1                 East Boston  125.0  42.364130 -71.029910  Entire home/apt
# 2                 East Boston  125.0  42.364130 -71.029910  Entire home/apt
# 3                 East Boston  125.0  42.364130 -71.029910  Entire home/apt
# 4                 East Boston  125.0  42.364130 -71.029910  Entire home/apt
# ...                       ...    ...        ...        ...              ...
# 182477              North End  110.0  42.365322 -71.055627  Entire home/apt
# 182478            East Boston  140.0  42.381106 -71.026179  Entire home/apt
# 182479                Roxbury  144.0  42.325558 -71.073339  Entire home/apt
# 182480                Roxbury  144.0  42.325558 -71.073339  Entire home/apt
# 182481             Dorchester   83.0  42.285236 -71.069907  Entire home/apt
#
#         number_of_reviews  review_scores_rating
# 0                      24                  4.96
# 1                      24                  4.96
# 2                      24                  4.96
# 3                      24                  4.96
# 4                      24                  4.96
# ...                   ...                   ...
# 182477                  1                  5.00
# 182478                  1                  5.00
# 182479                  2                  4.50
# 182480                  2                  4.50
# 182481                  1                  5.00
#
# [182430 rows x 11 columns]

# %%
data['review_date'] = pd.to_datetime(df['review_date'])

data= data[data['review_date'].dt.year.between(2019, 2023)]

# %%
comments_per_year = data['review_date'].dt.year.value_counts().sort_index()
print(comments_per_year)
# Out:
# 2019    23636
# 2020     9682
# 2021    20951
# 2022    36579
# 2023    45534
# Name: review_date, dtype: int64

# %%
corr = data.corr()
corr
# Out:
#                       listing_id  reviewer_id     price  latitude  longitude  \
# listing_id              1.000000     0.116905  0.016125 -0.043077  -0.003945
# reviewer_id             0.116905     1.000000 -0.046403 -0.037376   0.012029
# price                   0.016125    -0.046403  1.000000  0.029094   0.013210
# latitude               -0.043077    -0.037376  0.029094  1.000000   0.425890
# longitude              -0.003945     0.012029  0.013210  0.425890   1.000000
# number_of_reviews      -0.330101    -0.054660 -0.162282  0.252399   0.256565
# review_scores_rating   -0.048088    -0.058027  0.098029 -0.123030  -0.094537
#
#                       number_of_reviews  review_scores_rating
# listing_id                    -0.330101             -0.048088
# reviewer_id                   -0.054660             -0.058027
# price                         -0.162282              0.098029
# latitude                       0.252399             -0.123030
# longitude                      0.256565             -0.094537
# number_of_reviews              1.000000              0.190047
# review_scores_rating           0.190047              1.000000

# %%
data.info()
data1 = data.copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136382 entries, 14 to 182481
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   listing_id              136382 non-null  int64
#  1   review_date             136382 non-null  datetime64[ns]
#  2   reviewer_id             136382 non-null  int64
#  3   comments                136382 non-null  object
#  4   neighbourhood_cleansed  136382 non-null  object
#  5   price                   136382 non-null  float64
#  6   latitude                136382 non-null  float64
#  7   longitude               136382 non-null  float64
#  8   room_type               136382 non-null  object
#  9   number_of_reviews       136382 non-null  int64
#  10  review_scores_rating    136382 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(3)
# memory usage: 12.5+ MB

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('words')

data['comments'] = data['comments'].str.lower()
data['comments'] = data['comments'].str.replace(r"[^\w\s']", '')
data['comments'] = data['comments'].str.replace(r'\d+', '', regex=True)
data['comments'] = data['comments'].str.replace(r'\s+', ' ', regex=True)
data['comments'] =data['comments'].str.strip()
english_words = set(nltk.corpus.words.words())

def remove_stopwords(sent):
    stop_word = set(stopwords.words('english'))
    words = word_tokenize(sent)
    filter_word = [x for x in words if x not in stop_word and len(x)>2 and x in english_words]
    return filter_word

data['comments'] = data['comments'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
comments = data['comments']
list_doc = comments.tolist()

# %%
comments
# Out:
# 14        [partner, stayed, frank, apartment, several, g...
# 15        [much, apartment, rented, frank, place, perfec...
# 16        [stayed, frank, apartment, three, stay, excell...
# 17        [wonderful, bedroom, great, location, apartmen...
# 18        [great, place, amazing, location, highly, reco...
#                                 ...
# 182477    [wonderful, location, walk, around, north, end...
# 182478                            [great, deal, responsive]
# 182479    [stay, place, apartment, spacious, caught, sur...
# 182480     [good, place, solid, nice, park, inside, garage]
# 182481         [great, host, great, home, amazing, service]
# Name: comments, Length: 136382, dtype: object

# %%
list_doc
# Out:
# [['partner',
#   'stayed',
#   'frank',
#   'apartment',
#   'several',
#   'great',
#   'experience',
#   'frank',
#   'accommodating',
#   'thoughtful',
#   'needs',
#   'also',
#   'giving',
#   'good',
#   'amount',
#   'privacy',
#   'location',
#   'great',
#   'quiet',
#   'safe',
#   'neighborhood',
#   'would',
#   'definitely',
#   'stay',
#   'area'],
#  ['much',
#   'apartment',
#   'rented',
#   'frank',
#   'place',
#   'perfectly',
#   'clean',
#   'every',
#   'think',
#   'stay',
#   'boston',
#   'frank',
#   'great',
#   'host',
#   'responsive',
#   'made',
#   'everything',
#   'facilitate',
#   'stay',
#   'also',
#   'much',
#   'neighborhood',
#   'literally',
#   'end',
#   'street',
#   'nice',
#   'park',
#   'min',
#   'walk',
#   'highly',
#   'recommend',
#   'everyone'],
#  ['stayed',
#   'frank',
#   'apartment',
#   'three',
#   'stay',
#   'excellent',
#   'neighborhood',
#   'lovely',
#   'quiet',
#   'apartment',
#   'orderly',
#   'clean',
#   'comes',
#   'need',
#   'perfect',
#   'long',
#   'stay',
#   'boston'],
#  ['wonderful',
#   'bedroom',
#   'great',
#   'location',
#   'apartment',
#   'perfect',
#   'stay',
#   'proximity',
#   'many',
#   'provided',
#   'wonderful',
#   'boston',
#   'harbor',
#   'walkable',
#   'location',
#   'made',
#   'easy',
#   'reach',
#   'many',
#   'foot',
#   'private',
#   'driveway',
#   'made',
#   'parking',
#   'commuting',
#   'boston',
#   'breeze',
#   'thoroughly',
#   'stay'],
#  ['great', 'place', 'amazing', 'location', 'highly', 'recommend'],
#  ['apartment',
#   'perfect',
#   'short',
#   'long',
#   'term',
#   'stays',
#   'cozy',
#   'everything',
#   'could',
#   'need',
#   'especially',
#   'location',
#   'able',
#   'walk',
#   'along',
#   'harbor',
#   'bike'],
#  ['stayed',
#   'apartment',
#   'three',
#   'perfect',
#   'short',
#   'walk',
#   'public',
#   'transportation',
#   'lot',
#   'nice',
#   'nearby',
#   'apartment',
#   'exactly',
#   'kitchen',
#   'desk',
#   'provided',
#   'made',
#   'working',
#   'home',
#   'easy',
#   'frank',
#   'also',
#   'easily',
#   'reachable',
#   'phone',
#   'quick',
#   'respond',
#   'help',
#   'sort',
#   'thoroughly',
#   'stay',
#   'would',
#   'definitely',
#   'recommend'],
#  ['great',
#   'location',
#   'long',
#   'short',
#   'term',
#   'stays',
#   'stayed',
#   'week',
#   'work',
#   'assignment',
#   'minute',
#   'drive',
#   'depending',
#   'traffic',
#   'every',
#   'minute',
#   'stay',
#   'location',
#   'great',
#   'great',
#   'boston',
#   'harbor',
#   'short',
#   'walk',
#   'away',
#   'close',
#   'train',
#   'boston',
#   'east',
#   'boston',
#   'hidden',
#   'gem',
#   'great',
#   'delicious',
#   'food',
#   'dont',
#   'spot',
#   'justice',
#   'cute',
#   'homey',
#   'place',
#   'stay',
#   'would',
#   'highly',
#   'recommend',
#   'anyone',
#   'looking',
#   'stay',
#   'area',
#   'frank',
#   'great',
#   'always',
#   'responsive',
#   'help'],
#  ['great',
#   'place',
#   'spend',
#   'boston',
#   'place',
#   'quiet',
#   'area',
#   'east',
#   'boston',
#   'water',
#   'quick',
#   'walk',
#   'airport',
#   'blue',
#   'line',
#   'frank',
#   'nice',
#   'communicative',
#   'throughout',
#   'whole',
#   'stay',
#   'would',
#   'definitely',
#   'come',
#   'back',
#   'future'],
#  ['great', 'place', 'great', 'neighborhood'],
#  ['place',
#   'awesome',
#   'price',
#   'must',
#   'stay',
#   'area',
#   'close',
#   'downtown',
#   'relatively',
#   'cheap',
#   'clean',
#   'comfortable',
#   'tastefully',
#   'decorated'],
#  ['could',
#   'chosen',
#   'better',
#   'spot',
#   'first',
#   'stay',
#   'boston',
#   'absolutely',
#   'place',
#   'like',
#   'stay',
#   'hotel',
#   'gorgeous',
#   'old',
#   'school',
#   'building',
#   'comfy',
#   'bed',
#   'quiet',
#   'surroundings',
#   'right',
#   'thoughtful',
#   'minute',
#   'walk',
#   'crossing',
#   'station',
#   'minute',
#   'subway',
#   'ride',
#   'downtown',
#   'easier',
#   'terry',
#   'great',
#   'quick',
#   'respond',
#   'recommend',
#   'stay'],
#  ['easy',
#   'find',
#   'look',
#   'intersection',
#   'boulevard',
#   'mosque',
#   'tall',
#   'spire'],
#  ['studio',
#   'quiet',
#   'charming',
#   'conveniently',
#   'transportation',
#   'bed',
#   'comfortable',
#   'terry',
#   'thought',
#   'everything',
#   'much',
#   'though',
#   'wish',
#   'heating',
#   'could',
#   'better',
#   'recognize',
#   'charming',
#   'old',
#   'building',
#   'overall',
#   'lovely',
#   'stay'],
#  ['honestly',
#   'worked',
#   'perfectly',
#   'access',
#   'station',
#   'close',
#   'room',
#   'fun',
#   'funky',
#   'felt',
#   'safe',
#   'quiet',
#   'bed',
#   'comfortable',
#   'thing',
#   'would',
#   'stress',
#   'would',
#   'good',
#   'choice',
#   'someone',
#   'mobility',
#   'narrow',
#   'steep',
#   'walk',
#   'station',
#   'included',
#   'steep',
#   'hill',
#   'definitely',
#   'got',
#   'workout',
#   'everyday',
#   'otherwise',
#   'extremely',
#   'satisfied'],
#  ['nice', 'cozy', 'place', 'good', 'communication', 'interesting', 'boston'],
#  ['wonderful',
#   'clean',
#   'apartment',
#   'quiet',
#   'easy',
#   'access',
#   'public',
#   'transportation',
#   'friendly',
#   'host',
#   'would',
#   'visit',
#   'future'],
#  ['amazing',
#   'value',
#   'clean',
#   'well',
#   'everything',
#   'one',
#   'needs',
#   'nice',
#   'quiet',
#   'easy',
#   'walk',
#   'subway',
#   'line',
#   'straightforward'],
#  ['terry',
#   'responsive',
#   'accommodating',
#   'special',
#   'since',
#   'traveling',
#   'month',
#   'old',
#   'super',
#   'helpful',
#   'made',
#   'really',
#   'easy',
#   'realize',
#   'unit',
#   'third',
#   'floor',
#   'without',
#   'elevator',
#   'would',
#   'booked',
#   'ground',
#   'floor',
#   'knew',
#   'carry',
#   'stroller',
#   'baby',
#   'stuff',
#   'quite',
#   'times'],
#  ['great', 'place', 'close', 'train', 'super', 'value'],
#  ['beautiful', 'apartment', 'full', 'character', 'exactly', 'clean'],
#  ['nice',
#   'place',
#   'close',
#   'middle',
#   'town',
#   'thought',
#   'short',
#   'walk',
#   'quick',
#   'ride',
#   'see',
#   'seemingly',
#   'sketchy',
#   'neighborhood',
#   'never',
#   'quiet',
#   'everyone',
#   'boston',
#   'friendly',
#   'want',
#   'take',
#   'around',
#   'less',
#   'center',
#   'stuff'],
#  ['great',
#   'spot',
#   'stay',
#   'visiting',
#   'boston',
#   'much',
#   'immediate',
#   'area',
#   'block',
#   'everywhere',
#   'cute',
#   'building',
#   'clean'],
#  ['super', 'cute', 'quiet', 'old', 'charm', 'every', 'second'],
#  ['everything',
#   'great',
#   'place',
#   'quick',
#   'communication',
#   'easy',
#   'bit',
#   'concerned',
#   'known',
#   'area',
#   'boston',
#   'neighborhood',
#   'place',
#   'quite',
#   'safe',
#   'probably',
#   'wouldnt',
#   'wander',
#   'around',
#   'midnight',
#   'place',
#   'pretty',
#   'close',
#   'crossing',
#   'stop',
#   'made',
#   'convenient',
#   'get',
#   'downtown',
#   'overall',
#   'excellent',
#   'place',
#   'would',
#   'stay'],
#  ['guest',
#   'room',
#   'stylishly',
#   'decorated',
#   'clean',
#   'location',
#   'close',
#   'subway',
#   'line',
#   'get',
#   'town',
#   'quick',
#   'helpful',
#   'check',
#   'easy'],
#  ['location',
#   'right',
#   'subway',
#   'station',
#   'made',
#   'getting',
#   'around',
#   'super',
#   'easy',
#   'would',
#   'definitely',
#   'consider'],
#  ['fabulous',
#   'apartment',
#   'good',
#   'location',
#   'quirky',
#   'fun',
#   'left',
#   'great',
#   'folder',
#   'lots',
#   'useful',
#   'information',
#   'really',
#   'find',
#   'way',
#   'around',
#   'pointed',
#   'great',
#   'food',
#   'would',
#   'definitely',
#   'recommend',
#   'would',
#   'definitely',
#   'stay',
#   'visit',
#   'boston',
#   'thank',
#   'much'],
#  ['nice', 'place', 'cozy', 'stay'],
#  ['lovely',
#   'inn',
#   'neighborhood',
#   'outside',
#   'center',
#   'boston',
#   'room',
#   'super',
#   'comfortable',
#   'clean',
#   'neighborhood',
#   'great',
#   'safety',
#   'quiet',
#   'need',
#   'right',
#   'center',
#   'boston',
#   'place'],
#  ['room',
#   'everything',
#   'iron',
#   'microwave',
#   'laundry',
#   'everything',
#   'working',
#   'order',
#   'really',
#   'able',
#   'store',
#   'luggage',
#   'easy',
#   'walk',
#   'station',
#   'easy',
#   'wherever',
#   'would',
#   'definitely',
#   'stay',
#   'thank'],
#  ['wonderful',
#   'time',
#   'never',
#   'actually',
#   'met',
#   'like',
#   'really',
#   'leaving',
#   'luggage',
#   'promptly',
#   'easy',
#   'access',
#   'apartment',
#   'really',
#   'quirkiness',
#   'spotlessly',
#   'clean',
#   'min',
#   'walk',
#   'nearest',
#   'subway',
#   'terry',
#   'left',
#   'book',
#   'lots',
#   'eating',
#   'actually',
#   'ate',
#   'comfy',
#   'bed',
#   'perfect',
#   'noted',
#   'couple',
#   'people',
#   'said',
#   'wasnt',
#   'area',
#   'lot',
#   'nice',
#   'couple',
#   'dog',
#   'came',
#   'across',
#   'road',
#   'could',
#   'help',
#   'looking',
#   'map',
#   'time',
#   'ate',
#   'wee',
#   'restaurant',
#   'hill',
#   'highly',
#   'recommend',
#   'definitely',
#   'back',
#   'wonderful',
#   'city',
#   'boston'],
#  ['great', 'location', 'clean', 'overall', 'great', 'experience'],
#  ['great',
#   'place',
#   'stay',
#   'boston',
#   'room',
#   'charming',
#   'clean',
#   'great',
#   'walk',
#   'couple',
#   'subway',
#   'really',
#   'convenient',
#   'way',
#   'get',
#   'downtown',
#   'much',
#   'definitely',
#   'stay',
#   'future'],
#  ['das',
#   'ist',
#   'man',
#   'ist',
#   'check',
#   'super',
#   'easy',
#   'viertel',
#   'wir',
#   'man',
#   'nach',
#   'boston',
#   'die',
#   'ist',
#   'also',
#   'ich',
#   'das',
#   'trip',
#   'nach',
#   'boston'],
#  ['space',
#   'stylish',
#   'make',
#   'feel',
#   'warm',
#   'bed',
#   'quite',
#   'comfortable',
#   'plenty',
#   'closet',
#   'space',
#   'room',
#   'minute',
#   'walk',
#   'nearest',
#   'station',
#   'convenient',
#   'please',
#   'note',
#   'room',
#   'third',
#   'floor',
#   'walk',
#   'two',
#   'narrow',
#   'get',
#   'space',
#   'great',
#   'value',
#   'happy',
#   'found'],
#  ['nice', 'place', 'old', 'school', 'feel'],
#  ['nice', 'place', 'close', 'subway', 'short', 'walk'],
#  ['cozy',
#   'little',
#   'room',
#   'easy',
#   'entry',
#   'public',
#   'parking',
#   'decently',
#   'accessible'],
#  ['wonderful',
#   'little',
#   'place',
#   'great',
#   'hospitality',
#   'greet',
#   'location',
#   'quiet',
#   'neighborhood',
#   'small',
#   'room',
#   'comfortable'],
#  ['nice', 'place', 'except', 'difficulty', 'parking', 'visit'],
#  ['lovely', 'place', 'lovely'],
#  ['great', 'location'],
#  ['terry',
#   'place',
#   'great',
#   'clean',
#   'accurate',
#   'like',
#   'listing',
#   'minute',
#   'walk',
#   'crossing',
#   'station'],
#  ['great', 'stay'],
#  ['great',
#   'lots',
#   'luggage',
#   'plan',
#   'move',
#   'nice',
#   'hill',
#   'wouldnt',
#   'like',
#   'move',
#   'luggage',
#   'comfortable',
#   'room',
#   'everything',
#   'need',
#   'well',
#   'book',
#   'thanks',
#   'everything',
#   'ladies'],
#  ['thoroughly',
#   'stay',
#   'fort',
#   'hill',
#   'inn',
#   'historic',
#   'building',
#   'quaint',
#   'unique',
#   'charming',
#   'place',
#   'stay',
#   'close',
#   'proximity',
#   'orange',
#   'line',
#   'made',
#   'easy',
#   'get',
#   'around',
#   'kitchen',
#   'coffee',
#   'small',
#   'added',
#   'useful',
#   'convenience',
#   'could',
#   'easier',
#   'five'],
#  ['terry',
#   'excellent',
#   'kind',
#   'hostess',
#   'responsive',
#   'helpful',
#   'throughout',
#   'stay',
#   'area',
#   'private',
#   'safe',
#   'guidebook',
#   'helpful',
#   'informative',
#   'close',
#   'definitely',
#   'take',
#   'get',
#   'anywhere',
#   'super',
#   'cute',
#   'cozy',
#   'old',
#   'boston',
#   'home'],
#  ['small', 'old', 'boston', 'hotel', 'feel', 'everything'],
#  ['easy', 'check', 'clean', 'comfortable', 'thanks'],
#  ['fantastic',
#   'air',
#   'great',
#   'safe',
#   'walking',
#   'distance',
#   'everything',
#   'clean',
#   'neat',
#   'high',
#   'quality',
#   'rental'],
#  ['amazing', 'cozy', 'cute', 'place'],
#  ['attentive',
#   'reliable',
#   'host',
#   'nice',
#   'apartment',
#   'far',
#   'boston',
#   'offer'],
#  ['perfect', 'place', 'stay', 'clean', 'cozy', 'provided', 'quickly'],
#  ['stay',
#   'place',
#   'location',
#   'close',
#   'stop',
#   'get',
#   'central',
#   'quickly',
#   'good',
#   'place',
#   'people'],
#  ['terry',
#   'place',
#   'clean',
#   'comfortable',
#   'relatively',
#   'easy',
#   'get',
#   'simple',
#   'good',
#   'choice',
#   'need',
#   'somewhere',
#   'cozy',
#   'convenient'],
#  ['great', 'place', 'everything', 'location', 'phenomenal'],
#  ['apt',
#   'comfortable',
#   'pretty',
#   'nicely',
#   'decorated',
#   'stay',
#   'thank',
#   'terry'],
#  ['great', 'place'],
#  ['place',
#   'clean',
#   'close',
#   'public',
#   'transportation',
#   'community',
#   'bed',
#   'comfortable',
#   'stay'],
#  ['well',
#   'private',
#   'room',
#   'everything',
#   'could',
#   'need',
#   'location',
#   'quiet',
#   'easy',
#   'access',
#   'transit',
#   'issue',
#   'staircase',
#   'little',
#   'tricky',
#   'navigate',
#   'luggage',
#   'would',
#   'definitely',
#   'stay',
#   'highly',
#   'recommend'],
#  ['space',
#   'clean',
#   'well',
#   'everything',
#   'easy',
#   'get',
#   'boston',
#   'great',
#   'location',
#   'would',
#   'definitely',
#   'stay',
#   'thanks',
#   'great',
#   'place',
#   'stay'],
#  ['great',
#   'experience',
#   'family',
#   'great',
#   'location',
#   'easy',
#   'check',
#   'beautiful',
#   'house',
#   'plenty',
#   'home'],
#  ['absolutely',
#   'place',
#   'provided',
#   'everything',
#   'could',
#   'need',
#   'detergent',
#   'washer',
#   'apartment',
#   'safe',
#   'neighborhood',
#   'short',
#   'walk',
#   'public',
#   'transportation',
#   'everything',
#   'perfectly',
#   'set',
#   'clean',
#   'would',
#   'definitely',
#   'stay',
#   'visiting',
#   'boston',
#   'caution',
#   'winding',
#   'metal',
#   'spiral',
#   'staircase',
#   'access',
#   'bedroom',
#   'elderly',
#   'family',
#   'member',
#   'toddler',
#   'may',
#   'work',
#   'wasnt',
#   'main',
#   'stairway',
#   'saw',
#   'fine',
#   'giving',
#   'great',
#   'really',
#   'stay'],
#  ['great',
#   'place',
#   'convenient',
#   'location',
#   'clean',
#   'organized',
#   'minor',
#   'issue',
#   'toilet',
#   'fixed',
#   'soon',
#   'notified',
#   'would',
#   'highly',
#   'recommend',
#   'place',
#   'anyone',
#   'touring',
#   'boston'],
#  ['new',
#   'good',
#   'counter',
#   'space',
#   'couch',
#   'upper',
#   'space',
#   'comfortable',
#   'lower',
#   'level',
#   'damp',
#   'consider',
#   'basement',
#   'level',
#   'made',
#   'decorate',
#   'nicely',
#   'home',
#   'entering',
#   'old',
#   'home',
#   'smell',
#   'however',
#   'triggered',
#   'lower',
#   'level',
#   'high',
#   'humidity',
#   'apt',
#   'early',
#   'late',
#   'without',
#   'wanting',
#   'great',
#   'kitchen',
#   'reasonable',
#   'price',
#   'great',
#   'option',
#   'however',
#   'bit',
#   'walk',
#   'used',
#   'time',
#   'worked',
#   'fine',
#   'parking',
#   'problem',
#   'say',
#   'confused',
#   'booking',
#   'room',
#   'booked',
#   'reading',
#   'trip',
#   'advisor',
#   'seeing',
#   'different',
#   'name',
#   'listed',
#   'plugged',
#   'address',
#   'clarification',
#   'several',
#   'right',
#   'away',
#   'good',
#   'option',
#   'boston',
#   'hotel'],
#  ['beautifully',
#   'done',
#   'space',
#   'close',
#   'line',
#   'crossing',
#   'great',
#   'value',
#   'nice',
#   'space',
#   'stay'],
#  ['clean', 'exactly', 'owner', 'gave', 'quick', 'good', 'living'],
#  ['excellent',
#   'place',
#   'stay',
#   'would',
#   'definitely',
#   'consider',
#   'place',
#   'future'],
#  ['house',
#   'charming',
#   'near',
#   'subway',
#   'could',
#   'find',
#   'everything',
#   'borough',
#   'grocery',
#   'thanks'],
#  ['apartment',
#   'clean',
#   'like',
#   'good',
#   'location',
#   'close',
#   'downtown',
#   'public',
#   'transportation',
#   'bed',
#   'quick',
#   'respond',
#   'would',
#   'stay'],
#  ['place',
#   'amazing',
#   'location',
#   'perfect',
#   'whenever',
#   'question',
#   'received',
#   'timely',
#   'response',
#   'freedom',
#   'trail',
#   'saw',
#   'baseball',
#   'game',
#   'took',
#   'tour',
#   'sam',
#   'brewery',
#   'basilica',
#   'lady',
#   'perpetual',
#   'hope',
#   'aquarium',
#   'franklin',
#   'park',
#   'zoo',
#   'discovered',
#   'delightful',
#   'little',
#   'place',
#   'milkweed',
#   'area',
#   'days',
#   'happy',
#   'outcome',
#   'would',
#   'recommend',
#   'family',
#   'member'],
#  ['clean', 'stylish', 'place'],
#  [],
#  ['terry',
#   'place',
#   'clean',
#   'comfortable',
#   'home',
#   'away',
#   'home',
#   'terry',
#   'available',
#   'answer',
#   'quick',
#   'response',
#   'made',
#   'experience',
#   'much',
#   'simpler',
#   'first',
#   'experience',
#   'much',
#   'delighted',
#   'would',
#   'highly',
#   'recommend',
#   'terry'],
#  ['meet',
#   'person',
#   'quickly',
#   'nice',
#   'super',
#   'easy',
#   'well',
#   'wonderful',
#   'stay'],
#  ['place',
#   'beautiful',
#   'close',
#   'station',
#   'central',
#   'free',
#   'parking',
#   'couple',
#   'streets',
#   'away',
#   'car',
#   'definitely',
#   'recommend'],
#  ['apartment', 'super', 'clean', 'easy', 'access', 'way', 'enough', 'space'],
#  ['nice', 'place'],
#  ['great', 'place', 'exactly', 'listed', 'would', 'definitely', 'stay'],
#  ['great',
#   'stay',
#   'close',
#   'transport',
#   'boston',
#   'quiet',
#   'nice',
#   'character',
#   'apartment',
#   'everything'],
#  ['fort',
#   'hill',
#   'inn',
#   'perfect',
#   'time',
#   'boston',
#   'min',
#   'walk',
#   'orange',
#   'line',
#   'could',
#   'everywhere',
#   'without',
#   'car',
#   'apartment',
#   'lovely',
#   'great',
#   'living',
#   'room',
#   'kitchen',
#   'bedroom',
#   'spiral',
#   'staircase',
#   'clean',
#   'tell',
#   'take',
#   'pride',
#   'place',
#   'also',
#   'free',
#   'important',
#   'stay',
#   'touch',
#   'work',
#   'neighborhood',
#   'quiet',
#   'grocery',
#   'store',
#   'min',
#   'walk',
#   'next',
#   'time',
#   'boston',
#   'definitely',
#   'look',
#   'availability',
#   'terry',
#   'place'],
#  ['truly',
#   'gem',
#   'clean',
#   'quiet',
#   'conveniently',
#   'wonderful',
#   'place',
#   'come',
#   'home',
#   'end',
#   'day',
#   'historic',
#   'brownstone',
#   'way',
#   'original',
#   'house',
#   'amazing',
#   'value',
#   'price',
#   'cant',
#   'wait',
#   'back'],
#  [],
#  ['accommodating'],
#  ['beautiful',
#   'home',
#   'quiet',
#   'charming',
#   'neighborhood',
#   'boston',
#   'home',
#   'cutely',
#   'decorated',
#   'great',
#   'stay',
#   'found',
#   'home',
#   'super',
#   'convenient',
#   'public',
#   'transit',
#   'even',
#   'orange',
#   'transit',
#   'line',
#   'spacious',
#   'home',
#   'comfortable'],
#  ['fort',
#   'hill',
#   'inn',
#   'exactly',
#   'clean',
#   'clean',
#   'clean',
#   'quaintly',
#   'decorated',
#   'thought',
#   'every',
#   'single',
#   'thing',
#   'might',
#   'need',
#   'stay',
#   'best',
#   'area',
#   'still',
#   'felt',
#   'safe',
#   'short',
#   'walk',
#   'station',
#   'walking',
#   'back',
#   'little',
#   'steep',
#   'hill',
#   'problem',
#   'people',
#   'communicative',
#   'helpful',
#   'would',
#   'definitely',
#   'stay'],
#  ['place', 'great', 'would', 'love', 'book'],
#  ['terry', 'never', 'host', 'care', 'much', 'place', 'pretty'],
#  ['great',
#   'clean',
#   'beautiful',
#   'spot',
#   'great',
#   'location',
#   'apartment',
#   'warm',
#   'quiet',
#   'terry',
#   'super',
#   'fast',
#   'sure',
#   'come',
#   'back',
#   'future'],
#  ['great',
#   'time',
#   'terry',
#   'air',
#   'location',
#   'perfect',
#   'able',
#   'walk',
#   'lot',
#   'nice',
#   'place',
#   'relax',
#   'quiet',
#   'peaceful',
#   'thank',
#   'stay'],
#  ['terry',
#   'responsive',
#   'place',
#   'clean',
#   'comfortable',
#   'neighborhood',
#   'quiet',
#   'felt',
#   'safe',
#   'walking',
#   'home',
#   'dark',
#   'really',
#   'close',
#   'subway',
#   'minute',
#   'walk',
#   'park',
#   'would',
#   'stay'],
#  ['great', 'place', 'stay', 'coming', 'boston', 'highly', 'recommend'],
#  ['place',
#   'high',
#   'quality',
#   'well',
#   'everything',
#   'cook',
#   'home',
#   'available',
#   'kitchen',
#   'take',
#   'note',
#   'plan',
#   'cooking',
#   'home',
#   'grocery',
#   'store',
#   'away',
#   'huge',
#   'good',
#   'quality',
#   'piping',
#   'hot',
#   'water',
#   'shower',
#   'wonderfully',
#   'quiet',
#   'night',
#   'light',
#   'sleeper',
#   'min',
#   'walk',
#   'station',
#   'probably',
#   'train',
#   'ride',
#   'helpful',
#   'quick',
#   'replace',
#   'high',
#   'wasnt',
#   'working',
#   'used',
#   'washing',
#   'machine',
#   'basement',
#   'easy',
#   'operate',
#   'worked',
#   'would',
#   'definitely',
#   'recommend',
#   'place'],
#  ['stayed',
#   'four',
#   'business',
#   'travel',
#   'really',
#   'stay',
#   'location',
#   'unbeatable',
#   'great',
#   'host'],
#  ['pleasure',
#   'work',
#   'responsive',
#   'one',
#   'helpful',
#   'apartment',
#   'clean',
#   'bed',
#   'comfortable',
#   'stayed',
#   'open',
#   'much',
#   'curved',
#   'glass',
#   'great',
#   'comfort',
#   'throughout',
#   'apartment',
#   'stay',
#   'contact',
#   'next',
#   'stay',
#   'boston'],
#  ['great', 'location', 'super', 'convenient', 'stay'],
#  ['great',
#   'view',
#   'cozy',
#   'apartment',
#   'something',
#   'note',
#   'temperature',
#   'controllable',
#   'space',
#   'heater',
#   'provided'],
#  ['great', 'location', 'view', 'incredible', 'pleasant', 'stay'],
#  ['place', 'fabulous', 'clean', 'everything', 'location', 'spectacular'],
#  ['nice', 'place'],
#  ['amazing',
#   'location',
#   'murphy',
#   'bed',
#   'comfortable',
#   'kitchen',
#   'great',
#   'also',
#   'plus',
#   'water',
#   'pressure',
#   'fantastic',
#   'older',
#   'home',
#   'quiet',
#   'neighborhood',
#   'great',
#   'walking',
#   'neighborhood'],
#  ['great',
#   'location',
#   'boston',
#   'favorite',
#   'city',
#   'live',
#   'back',
#   'bay',
#   'favorite',
#   'neighborhood',
#   'studio',
#   'favorite',
#   'street',
#   'feel',
#   'lucky',
#   'stayed',
#   'quiet',
#   'street',
#   'little',
#   'traffic',
#   'step',
#   'outside',
#   'like',
#   'upscale',
#   'urban',
#   'century',
#   'neighborhood',
#   'well',
#   'except',
#   'hear',
#   'surrounded',
#   'charming',
#   'old',
#   'well',
#   'kept',
#   'short',
#   'walk',
#   'river',
#   'shopping',
#   'public',
#   'transportation',
#   'recommend',
#   'walking',
#   'commonwealth',
#   'avenue',
#   'mall',
#   'call',
#   'mall',
#   'exceptionally',
#   'beautiful',
#   'median',
#   'strip',
#   'public',
#   'studio',
#   'high',
#   'bay',
#   'decorative',
#   'fireplace',
#   'certain',
#   'old',
#   'world',
#   'excellent',
#   'hostess',
#   'cable',
#   'promptly',
#   'even',
#   'brand',
#   'new',
#   'recommendation',
#   'check',
#   'good',
#   'bike',
#   'system',
#   'pedal',
#   'around'],
#  ['helpful', 'booking', 'accommodating', 'thank', 'much', 'pleasant', 'stay'],
#  [],
#  ['cute',
#   'apartment',
#   'nice',
#   'building',
#   'good',
#   'parking',
#   'within',
#   'everything',
#   'went',
#   'easy',
#   'drive',
#   'price',
#   'nice',
#   'get',
#   'separate',
#   'inconvenient',
#   'considering',
#   'send',
#   'maybe',
#   'message',
#   'place',
#   'clean',
#   'furnished',
#   'soft',
#   'nice',
#   'heating',
#   'iffy',
#   'sweating',
#   'hot',
#   'chill',
#   'realize',
#   'said',
#   'check',
#   'meant',
#   'going',
#   'leaving',
#   'love',
#   'stay',
#   'sure',
#   'understand',
#   'party',
#   'clearly',
#   'want',
#   'happen'],
#  ['lance',
#   'place',
#   'great',
#   'outstanding',
#   'value',
#   'restaurant',
#   'next',
#   'door',
#   'literally',
#   'away',
#   'amazing',
#   'experience',
#   'highly'],
#  ['house',
#   'rather',
#   'nice',
#   'much',
#   'person',
#   'size',
#   'well',
#   'place',
#   'boston',
#   'mobile',
#   'rather',
#   'easy',
#   'use',
#   'lot',
#   'information',
#   'whats',
#   'around'],
#  ['everything',
#   'great',
#   'amazing',
#   'restaurant',
#   'literally',
#   'next',
#   'door',
#   'great',
#   'food',
#   'decent',
#   'travel',
#   'time',
#   'city',
#   'center',
#   'great',
#   'price',
#   'included',
#   'would',
#   'book',
#   'sure'],
#  ['value',
#   'level',
#   'location',
#   'minute',
#   'walk',
#   'lance',
#   'thermostat',
#   'timely',
#   'manner',
#   'check',
#   'worked',
#   'well'],
#  ['close', 'local', 'brewery', 'great'],
#  [],
#  ['awesome',
#   'extended',
#   'stay',
#   'home',
#   'undergoing',
#   'apartment',
#   'well',
#   'nice',
#   'like',
#   'door',
#   'sample',
#   'menu',
#   'upscale',
#   'restaurant',
#   'next',
#   'door',
#   'cute',
#   'area',
#   'historic',
#   'super',
#   'convenient',
#   'highway',
#   'mass',
#   'ave',
#   'mall',
#   'travel',
#   'inside',
#   'outside',
#   'building',
#   'best',
#   'choice',
#   'light',
#   'sleeper',
#   'street',
#   'parking',
#   'never',
#   'problem'],
#  ['recent',
#   'stay',
#   'excellent',
#   'value',
#   'overall',
#   'apartment',
#   'high',
#   'hardwood',
#   'numerous',
#   'made',
#   'welcoming',
#   'washer',
#   'central',
#   'dishwasher',
#   'added',
#   'convenience',
#   'though',
#   'minor',
#   'water',
#   'heating',
#   'resolved',
#   'lance',
#   'apartment',
#   'comfortable',
#   'thoughtful',
#   'standout',
#   'next',
#   'nice',
#   'restaurant',
#   'dock',
#   'convenient',
#   'presence',
#   'eleven',
#   'relatively',
#   'close',
#   'distance',
#   'stop',
#   'shop',
#   'target',
#   'also',
#   'convenient',
#   'however',
#   'noise',
#   'busy',
#   'could',
#   'disruptive',
#   'night',
#   'downside',
#   'neighborhood',
#   'safety',
#   'concern',
#   'food',
#   'stolen',
#   'couple',
#   'place',
#   'remains',
#   'comfortable',
#   'affordable',
#   'option',
#   'overall',
#   'recommend',
#   'value'],
#  ['spent',
#   'weekend',
#   'beautiful',
#   'historic',
#   'unique',
#   'style',
#   'apartment',
#   'quite',
#   'experience',
#   'great',
#   'close',
#   'major',
#   'boston',
#   'several',
#   'excellent',
#   'tip',
#   'sure',
#   'recommend',
#   'place',
#   'place',
#   'charming',
#   'thank'],
#  ['place',
#   'exotically',
#   'beautiful',
#   'comfortable',
#   'immaculate',
#   'well',
#   'everything',
#   'could',
#   'possibly',
#   'need',
#   'wonderful',
#   'stay',
#   'addition',
#   'tasty',
#   'breakfast',
#   'daily',
#   'basis',
#   'also',
#   'perfect',
#   'location',
#   'boston',
#   'quiet',
#   'historic',
#   'neighborhood',
#   'full',
#   'small',
#   'staff',
#   'went',
#   'way',
#   'make',
#   'stay',
#   'enjoyable',
#   'highly',
#   'recommend',
#   'looking',
#   'forward',
#   'return',
#   'visit'],
#  ['luxury',
#   'truly',
#   'exemplary',
#   'love',
#   'browsing',
#   'chain',
#   'unit',
#   'part',
#   'historic',
#   'home',
#   'yet',
#   'peaceful',
#   'part',
#   'boston',
#   'beautiful',
#   'interior',
#   'thoughtful',
#   'simply',
#   'many',
#   'start',
#   'listing',
#   'review',
#   'thanks',
#   'staff'],
#  ['romantic',
#   'exotic',
#   'retreat',
#   'stay',
#   'accommodation',
#   'treat',
#   'immaculate',
#   'full',
#   'thoughtful',
#   'like',
#   'next',
#   'bed',
#   'breakfast',
#   'room',
#   'stay',
#   'high',
#   'end',
#   'hotel',
#   'experience',
#   'convenient',
#   'boston',
#   'offer',
#   'high',
#   'end',
#   'bedding',
#   'bed',
#   'beautiful',
#   'furniture',
#   'two',
#   'hundred',
#   'year',
#   'old',
#   'wooden',
#   'amazing',
#   'kitchen',
#   'bathroom',
#   'also',
#   'fully',
#   'anything',
#   'would',
#   'need',
#   'staff',
#   'fabulous',
#   'one',
#   'favorite',
#   'definitely',
#   'return'],
#  ['beautiful', 'historical', 'home', 'great', 'location'],
#  ['key',
#   'reason',
#   'stay',
#   'experience',
#   'unique',
#   'lodging',
#   'destination',
#   'traveling',
#   'suite',
#   'magical',
#   'destination',
#   'exquisitely',
#   'furnished',
#   'opulent',
#   'unit',
#   'split',
#   'plan',
#   'lush',
#   'bedroom',
#   'area',
#   'modern',
#   'bathroom',
#   'attention',
#   'detail',
#   'seen',
#   'right',
#   'fresh',
#   'bedside',
#   'feel',
#   'like',
#   'royalty',
#   'sleeping',
#   'rich',
#   'appreciate',
#   'power',
#   'various',
#   'electric',
#   'stayed',
#   'helping',
#   'daughter',
#   'move',
#   'boston',
#   'certainly',
#   'stay',
#   'location',
#   'central',
#   'charm',
#   'key',
#   'away',
#   'treat',
#   'stay'],
#  ['suite',
#   'comfortable',
#   'beautiful',
#   'fabulous',
#   'value',
#   'location',
#   'fantastic',
#   'walking',
#   'distance',
#   'main',
#   'even',
#   'lovely',
#   'mile',
#   'walk',
#   'downtown',
#   'boston',
#   'bed',
#   'soft',
#   'cozy',
#   'ever',
#   'slept',
#   'even',
#   'bath',
#   'luxurious',
#   'also',
#   'included',
#   'lovely',
#   'like',
#   'coffee',
#   'cereal',
#   'far',
#   'space',
#   'youd',
#   'get',
#   'hotel',
#   'boston',
#   'area',
#   'great',
#   'price',
#   'definitely',
#   'look',
#   'first',
#   'return',
#   'boston'],
#  ['charming',
#   'clean',
#   'freak',
#   'place',
#   'super',
#   'clean',
#   'husband',
#   'really',
#   'time',
#   'would',
#   'recommend',
#   'anyone',
#   'experience',
#   'area',
#   'wanting',
#   'clean',
#   'place',
#   'end',
#   'nights'],
#  ['location',
#   'amazing',
#   'cute',
#   'part',
#   'town',
#   'many',
#   'yummy',
#   'easily',
#   'short',
#   'walking',
#   'distance',
#   'unit',
#   'unique',
#   'cozy',
#   'aesthetically',
#   'pleasing',
#   'stayed',
#   'rainy',
#   'night',
#   'heaven',
#   'surprisingly',
#   'loud',
#   'thought',
#   'would',
#   'bed',
#   'comfortable',
#   'would',
#   'stay',
#   'excellent',
#   'host',
#   'well'],
#  ['place',
#   'amazing',
#   'place',
#   'stay',
#   'boston',
#   'excellent',
#   'location',
#   'amazing',
#   'communicative',
#   'host',
#   'would',
#   'highly',
#   'recommend',
#   'two',
#   'note',
#   'future',
#   'case',
#   'immediately',
#   'obvious',
#   'climb',
#   'couple',
#   'get',
#   'place',
#   'nothing',
#   'insane',
#   'worth',
#   'keeping',
#   'mind',
#   'even',
#   'though',
#   'place',
#   'listening',
#   'entire',
#   'home',
#   'really',
#   'entirely',
#   'suite',
#   'within',
#   'building',
#   'think',
#   'something',
#   'hotel',
#   'check',
#   'area',
#   'think',
#   'might',
#   'building',
#   'times',
#   'suite',
#   'still',
#   'private',
#   'might',
#   'deviate',
#   'slightly',
#   'think',
#   'going',
#   'turnkey',
#   'entire',
#   'home',
#   'interact',
#   'host'],
#  ['fantastic',
#   'place',
#   'stay',
#   'super',
#   'comfortable',
#   'kind',
#   'welcoming',
#   'host',
#   'house',
#   'quick',
#   'walk',
#   'subway',
#   'station',
#   'getting',
#   'around',
#   'boston',
#   'breeze',
#   'would',
#   'highly',
#   'recommend',
#   'place',
#   'couple',
#   'traveling',
#   'area'],
#  ['good'],
#  ['amazing',
#   'host',
#   'stayed',
#   'truly',
#   'home',
#   'welcoming',
#   'environment',
#   'location',
#   'hard',
#   'beat',
#   'private',
#   'room',
#   'gorgeous',
#   'garden',
#   'great',
#   'place',
#   'even',
#   'better',
#   'host'],
#  ['excellent',
#   'host',
#   'stay',
#   'place',
#   'pleasant',
#   'comfortable',
#   'room',
#   'cosy',
#   'comfortable',
#   'house',
#   'super',
#   'clean',
#   'stay',
#   'great',
#   'location',
#   'easily',
#   'accessible',
#   'within',
#   'min',
#   'walk',
#   'distance',
#   'train',
#   'bus',
#   'company',
#   'far',
#   'well',
#   'doggo',
#   'seen',
#   'would',
#   'highly',
#   'recommend',
#   'listing'],
#  ['excellent',
#   'host',
#   'newly',
#   'private',
#   'bathroom',
#   'place',
#   'conveniently',
#   'close',
#   'green',
#   'stop',
#   'orange',
#   'line'],
#  ['fantastic',
#   'place',
#   'nice',
#   'host',
#   'easygoing',
#   'guy',
#   'place',
#   'clean',
#   'tidy',
#   'great',
#   'location',
#   'cute',
#   'great',
#   'nearby',
#   'private',
#   'bathroom',
#   'huge',
#   'plus',
#   'stayed',
#   'course',
#   'internship',
#   'overall',
#   'good',
#   'summer'],
#  ['excellent',
#   'host',
#   'four',
#   'month',
#   'stay',
#   'room',
#   'comfortable',
#   'friendly',
#   'accommodating',
#   'convenient',
#   'location',
#   'close',
#   'orange',
#   'line',
#   'also',
#   'huge',
#   'plus',
#   'highly',
#   'recommend'],
#  ['really',
#   'nice',
#   'guy',
#   'beautiful',
#   'home',
#   'kitchen',
#   'got',
#   'really',
#   'nice',
#   'like',
#   'cook',
#   'great',
#   'eat',
#   'location',
#   'perfect',
#   'without',
#   'vehicle',
#   'skip',
#   'beat',
#   'close',
#   'many',
#   'grocery',
#   'well',
#   'public',
#   'transportation',
#   'really',
#   'beautiful',
#   'pond',
#   'great',
#   'run',
#   'walk',
#   'star',
#   'experience',
#   'recommend',
#   'anyone',
#   'visiting',
#   'boston'],
#  ['amazing',
#   'host',
#   'friendly',
#   'interesting',
#   'accommodating',
#   'first',
#   'night',
#   'stayed',
#   'extended',
#   'stay',
#   'rest',
#   'month',
#   'place',
#   'clean',
#   'kitchen',
#   'amazing',
#   'location',
#   'convenient',
#   'find',
#   'available',
#   'place',
#   'stay'],
#  ['like',
#   'written',
#   'great',
#   'place',
#   'stay',
#   'kind',
#   'easy',
#   'going',
#   'never',
#   'extremely',
#   'clean',
#   'house',
#   'come',
#   'twice',
#   'month',
#   'neighborhood',
#   'bit',
#   'love',
#   'beauty',
#   'neighborhood',
#   'get',
#   'private',
#   'bedroom',
#   'private',
#   'bathroom',
#   'really',
#   'nice',
#   'climbing',
#   'bedroom',
#   'floor',
#   'beautiful',
#   'multiple',
#   'garden',
#   'view',
#   'onto'],
#  ['find',
#   'comfortable',
#   'room',
#   'large',
#   'closet',
#   'ample',
#   'dresser',
#   'drawers',
#   'desk',
#   'garden',
#   'perfect',
#   'month',
#   'boston',
#   'affable',
#   'host',
#   'generously',
#   'yard',
#   'living',
#   'room',
#   'new',
#   'kitchen',
#   'available',
#   'guest',
#   'location',
#   'outstanding',
#   'pond',
#   'arboretum',
#   'public',
#   'transportation',
#   'varied',
#   'wonderful'],
#  ['looking',
#   'place',
#   'welcoming',
#   'extremely',
#   'accommodating',
#   'comfortable',
#   'room',
#   'private',
#   'immaculately',
#   'kept',
#   'bathroom',
#   'close',
#   'town',
#   'center',
#   'ideal',
#   'place'],
#  ['place',
#   'great',
#   'stay',
#   'boston',
#   'house',
#   'amazing',
#   'location',
#   'unbeatable',
#   'close',
#   'subway',
#   'great',
#   'host',
#   'comfortable',
#   'stay'],
#  ['beautiful', 'home', 'accommodating', 'host'],
#  ['clean',
#   'comfortable',
#   'conveniently',
#   'near',
#   'green',
#   'street',
#   'terrific',
#   'host',
#   'always',
#   'respectful',
#   'friendly',
#   'thoroughly',
#   'delightful',
#   'chat',
#   'real',
#   'home',
#   'away',
#   'home'],
#  ['amazing',
#   'host',
#   'beautiful',
#   'clean',
#   'home',
#   'great',
#   'location',
#   'close',
#   'orange'],
#  ['brilliant', 'host', 'home', 'home', 'great', 'really', 'helpful'],
#  ['place',
#   'clean',
#   'comfortable',
#   'blue',
#   'downtown',
#   'within',
#   'walking',
#   'distance',
#   'need',
#   'car',
#   'entire',
#   'stay',
#   'boston',
#   'heat',
#   'wave',
#   'nice',
#   'house',
#   'come',
#   'home',
#   'friendly',
#   'easygoing',
#   'host'],
#  ['great',
#   'stay',
#   'place',
#   'quiet',
#   'neighborhood',
#   'good',
#   'nearby',
#   'min',
#   'walk',
#   'orange',
#   'line',
#   'street',
#   'parking',
#   'easily',
#   'accessible',
#   'well',
#   'room',
#   'also',
#   'clean',
#   'everything',
#   'need',
#   'kind',
#   'person',
#   'fun',
#   'talk',
#   'would',
#   'definitely',
#   'recommend',
#   'anyone',
#   'stay',
#   'place'],
#  ['house',
#   'definitely',
#   'one',
#   'best',
#   'stayed',
#   'visit',
#   'boston',
#   'available',
#   'helpful',
#   'providing',
#   'guidance',
#   'way',
#   'around',
#   'city',
#   'check',
#   'early',
#   'well',
#   'check',
#   'late',
#   'great',
#   'boon',
#   'quite',
#   'bit',
#   'luggage',
#   'personally',
#   'present',
#   'door',
#   'receive',
#   'even',
#   'carry',
#   'luggage',
#   'room',
#   'bedroom',
#   'lovely',
#   'one',
#   'flooded',
#   'light',
#   'garden',
#   'kitchen',
#   'drawing',
#   'room',
#   'also',
#   'connected',
#   'another',
#   'bonus',
#   'especially',
#   'sports',
#   'finally',
#   'add',
#   'charm',
#   'place',
#   'little',
#   'brick',
#   'adorable',
#   'puppy',
#   'house',
#   'safe',
#   'neighborhood',
#   'close',
#   'train',
#   'bus',
#   'took',
#   'heart',
#   'city',
#   'within',
#   'half',
#   'hour',
#   'number',
#   'grocery',
#   'well',
#   'close',
#   'keen',
#   'getting',
#   'exercise',
#   'natural',
#   'surroundings',
#   'lovely',
#   'well',
#   'pond',
#   'close',
#   'walk',
#   'around',
#   'overall',
#   'husband',
#   'great',
#   'experience',
#   'place',
#   'would',
#   'gladly',
#   'stay'],
#  ['second',
#   'stay',
#   'home',
#   'first',
#   'choice',
#   'come',
#   'back',
#   'boston',
#   'lived',
#   'comfortable',
#   'home',
#   'neighborhood',
#   'good',
#   'convenient',
#   'bus',
#   'subway',
#   'transportation'],
#  ['fun',
#   'host',
#   'lot',
#   'eating',
#   'together',
#   'watching',
#   'football',
#   'new',
#   'dog',
#   'always',
#   'friendly',
#   'lot',
#   'sometimes',
#   'even',
#   'dog',
#   'still',
#   'seem',
#   'comfortable',
#   'area',
#   'great',
#   'walking',
#   'bus',
#   'stop',
#   'orange',
#   'big',
#   'grocery',
#   'several',
#   'smaller',
#   'nearby',
#   'also',
#   'nice',
#   'yoga',
#   'studio',
#   'recommend',
#   'parking',
#   'mostly',
#   'easy',
#   'street'],
#  ['stay',
#   'much',
#   'great',
#   'location',
#   'explore',
#   'boston',
#   'downtown',
#   'easy',
#   'reach',
#   'via',
#   'train',
#   'bus',
#   'grocery',
#   'everything',
#   'else',
#   'need',
#   'walking',
#   'distance'],
#  ['great',
#   'stay',
#   'warm',
#   'welcoming',
#   'lots',
#   'helpful',
#   'advice',
#   'area',
#   'feel',
#   'beautiful',
#   'house',
#   'everything',
#   'order',
#   'feel',
#   'right',
#   'home',
#   'two',
#   'stayed'],
#  ['nice',
#   'welcoming',
#   'guest',
#   'house',
#   'comfortable',
#   'clean',
#   'spacious',
#   'detail',
#   'nice',
#   'position'],
#  ['thank',
#   'stay',
#   'home',
#   'really',
#   'time',
#   'also',
#   'back',
#   'boston',
#   'area',
#   'felt',
#   'truly',
#   'like',
#   'home',
#   'quickly',
#   'way',
#   'plain',
#   'lovely',
#   'district',
#   'bye',
#   'antal'],
#  ['perfect',
#   'place',
#   'silent',
#   'min',
#   'walk',
#   'around',
#   'house',
#   'like',
#   'new',
#   'clean',
#   'beautiful',
#   'cute',
#   'especially',
#   'recommend'],
#  ['place',
#   'comfortable',
#   'clean',
#   'convenient',
#   'minute',
#   'walk',
#   'gate',
#   'stress',
#   'level',
#   'know',
#   'someplace',
#   'special'],
#  ['wonderful',
#   'stay',
#   'room',
#   'large',
#   'substantial',
#   'amount',
#   'away',
#   'need',
#   'air',
#   'conditioner',
#   'space',
#   'heater',
#   'fan',
#   'cooking',
#   'extra',
#   'bedding',
#   'atef',
#   'made',
#   'available',
#   'anything',
#   'right',
#   'next',
#   'bus',
#   'took',
#   'right',
#   'office',
#   'well',
#   'also',
#   'much',
#   'light',
#   'since',
#   'lower',
#   'floor',
#   'pleasantly',
#   'well',
#   'worth',
#   'money',
#   'stay'],
#  ['place',
#   'clean',
#   'well',
#   'neighborhood',
#   'gorgeous',
#   'close',
#   'bunker',
#   'hill',
#   'monument',
#   'quick',
#   'walk',
#   'easy',
#   'fit',
#   'business',
#   'trip',
#   'clearly',
#   'weather',
#   'bit',
#   'cold',
#   'enjoy',
#   'outdoor',
#   'space',
#   'often',
#   'nice',
#   'bit',
#   'outdoors',
#   'outside',
#   'window',
#   'also',
#   'privacy'],
#  ['place',
#   'nice',
#   'clean',
#   'spacious',
#   'area',
#   'great',
#   'picturesque',
#   'area',
#   'boston',
#   'right',
#   'way',
#   'freedom',
#   'trail',
#   'shopping',
#   'center',
#   'min',
#   'away',
#   'place',
#   'whole',
#   'nice',
#   'around',
#   'far',
#   'orange',
#   'subway',
#   'line',
#   'stop',
#   'work',
#   'commute',
#   'every',
#   'day',
#   'south',
#   'station',
#   'bit',
#   'pain',
#   'imagine',
#   'great',
#   'place',
#   'stay'],
#  ['although',
#   'stay',
#   'boston',
#   'thought',
#   'place',
#   'tidy',
#   'host',
#   'let',
#   'stay',
#   'couple',
#   'check',
#   'time',
#   'disappointed',
#   'although',
#   'pay',
#   'extra',
#   'guest',
#   'stay',
#   'people',
#   'total',
#   'two',
#   'coffee',
#   'two',
#   'place',
#   'accommodate',
#   'especially',
#   'charging',
#   'hundred',
#   'extra',
#   'per',
#   'guest',
#   'also',
#   'disappointed',
#   'although',
#   'page',
#   'include',
#   'information',
#   'host',
#   'would',
#   'give',
#   'information',
#   'cash',
#   'atef',
#   'polite',
#   'quick',
#   'communication',
#   'live',
#   'space',
#   'would',
#   'say',
#   'location',
#   'best',
#   'thing',
#   'place'],
#  ['lovely',
#   'studio',
#   'well',
#   'situated',
#   'quiet',
#   'beautiful',
#   'neighborhood',
#   'easy',
#   'access',
#   'historic',
#   'boston',
#   'via',
#   'subway',
#   'thoroughly',
#   'stay'],
#  ['place', 'great', 'strongly', 'recommend'],
#  ['lovely',
#   'spot',
#   'great',
#   'location',
#   'bra',
#   'couple',
#   'favorite',
#   'easy',
#   'access',
#   'bike',
#   'station',
#   'great',
#   'bike',
#   'get',
#   'anywhere',
#   'else',
#   'city',
#   'check',
#   'blue',
#   'adventure',
#   'pass',
#   'option',
#   'unlimited',
#   'great',
#   'way',
#   'get',
#   'tea',
#   'one',
#   'block',
#   'away',
#   'lovely',
#   'neighborhood',
#   'feeling',
#   'little',
#   'coffee',
#   'shop',
#   'morning',
#   'gem',
#   'plug',
#   'neighborhood',
#   'kind',
#   'strange',
#   'vast',
#   'land',
#   'cave',
#   'also',
#   'one',
#   'block',
#   'away',
#   'nice',
#   'late',
#   'night',
#   'option',
#   'night',
#   'perfect',
#   'timing',
#   'kitchen',
#   'still',
#   'open',
#   'tasty',
#   'snack',
#   'crowd',
#   'gone',
#   'bartender',
#   'good',
#   'book',
#   'feel',
#   'like',
#   'might',
#   'little',
#   'less',
#   'pleasant',
#   'least',
#   'much',
#   'scene',
#   'full',
#   'crowded',
#   'apartment',
#   'nice',
#   'light',
#   'sunny',
#   'day',
#   'great',
#   'unit',
#   'somewhat',
#   'low',
#   'tall',
#   'person',
#   'like',
#   'open',
#   'feel',
#   'spacious',
#   'entrance',
#   'nice',
#   'bit',
#   'adventure',
#   'character',
#   'way',
#   'might',
#   'access',
#   'limited',
#   'mobility',
#   'atef',
#   'great',
#   'communicator',
#   'responsive',
#   'clear',
#   'information',
#   'everything',
#   'felt',
#   'super',
#   'clean',
#   'clearly',
#   'unit',
#   'guest',
#   'suite',
#   'one',
#   'actually',
#   'bit',
#   'like',
#   'hotel',
#   'room',
#   'someone',
#   'home',
#   'plus',
#   'part',
#   'appeal',
#   'warmth',
#   'kitchen',
#   'stuff',
#   'want',
#   'cook',
#   'lot',
#   'might',
#   'find',
#   'looking',
#   'par',
#   'course',
#   'point',
#   'could',
#   'find',
#   'serrated',
#   'knife',
#   'cut',
#   'loaf',
#   'bread',
#   'example',
#   'although',
#   'bet',
#   'actually',
#   'atef',
#   'might',
#   'well',
#   'brought',
#   'one',
#   'upstairs',
#   'clearly',
#   'attentive',
#   'host',
#   'think',
#   'major',
#   'concern',
#   'iron',
#   'stove',
#   'fire',
#   'extinguisher',
#   'open',
#   'entrance',
#   'door',
#   'one',
#   'end',
#   'unit',
#   'bed',
#   'shower',
#   'end',
#   'somehow',
#   'manage',
#   'leave',
#   'something',
#   'fire',
#   'take',
#   'long',
#   'shower',
#   'fall',
#   'deep',
#   'sleep',
#   'find',
#   'stuck',
#   'side',
#   'building',
#   'well',
#   'start',
#   'fire',
#   'might',
#   'still',
#   'like',
#   'see',
#   'stepladder',
#   'side',
#   'apartment',
#   'emergency',
#   'exit',
#   'option',
#   'street',
#   'side'],
#  ['atef',
#   'welcoming',
#   'host',
#   'lot',
#   'area',
#   'space',
#   'quite',
#   'large',
#   'incredibly',
#   'peaceful',
#   'apartment',
#   'close',
#   'bunker',
#   'hill',
#   'monument',
#   'nice',
#   'bonus'],
#  ['great',
#   'hospitality',
#   'comfortable',
#   'stay',
#   'clean',
#   'stylish',
#   'place',
#   'air',
#   'conditioned',
#   'luggage',
#   'heat',
#   'relief',
#   'laundry',
#   'outside',
#   'room',
#   'find',
#   'everything',
#   'need',
#   'cleaning',
#   'kit',
#   'microwave',
#   'shampoo',
#   'clothes',
#   'laundry',
#   'detergent',
#   'perfect',
#   'neighborhood',
#   'garden',
#   'beautiful',
#   'could',
#   'really',
#   'feel',
#   'atef',
#   'passion',
#   'care',
#   'place',
#   'atef',
#   'great',
#   'host',
#   'flexible',
#   'arrival',
#   'departure',
#   'time',
#   'also',
#   'gave',
#   'great',
#   'local',
#   'pleasant',
#   'conversation',
#   'definitely',
#   'would',
#   'visit',
#   'area',
#   'lastly',
#   'hook',
#   'garden',
#   'gate',
#   'bit',
#   'difficult',
#   'find',
#   'first',
#   'petite',
#   'side',
#   'hook',
#   'blind',
#   'spot',
#   'atef',
#   'gave',
#   'yes',
#   'problem',
#   'knew',
#   'find'],
#  ['studio',
#   'great',
#   'work',
#   'trip',
#   'boston',
#   'everything',
#   'little',
#   'garden',
#   'serene',
#   'quiet',
#   'spot',
#   'busy',
#   'days',
#   'town',
#   'studio',
#   'extraordinarily',
#   'cute',
#   'quaint',
#   'part'],
#  ['atef',
#   'host',
#   'responsive',
#   'detailed',
#   'pleasure',
#   'meeting',
#   'person',
#   'informative',
#   'anything',
#   'tour',
#   'guide',
#   'great',
#   'city',
#   'boston',
#   'grad',
#   'school',
#   'check',
#   'easy',
#   'provided',
#   'detailed',
#   'description',
#   'point',
#   'felt',
#   'first',
#   'room',
#   'spacious',
#   'clean',
#   'bathroom',
#   'couch',
#   'kitchen',
#   'firm',
#   'bed',
#   'traveling',
#   'alone',
#   'felt',
#   'completely',
#   'safe',
#   'apartment',
#   'neighborhood',
#   'place',
#   'half',
#   'block',
#   'bunker',
#   'hill',
#   'monument'],
#  ['great',
#   'location',
#   'relative',
#   'event',
#   'boston',
#   'convention',
#   'able',
#   'walk',
#   'one',
#   'day',
#   'close',
#   'whole',
#   'quite',
#   'comfortable',
#   'thanks'],
#  ['place',
#   'really',
#   'good',
#   'location',
#   'minute',
#   'walk',
#   'heart',
#   'boston',
#   'scenic',
#   'path',
#   'bother',
#   'bit',
#   'spotty',
#   'small',
#   'didnt',
#   'even',
#   'bother',
#   'turn',
#   'would',
#   'stay'],
#  ['fantastic',
#   'comfortable',
#   'place',
#   'everything',
#   'need',
#   'outside',
#   'garden',
#   'fountain',
#   'soothing',
#   'looking',
#   'really',
#   'experience',
#   'quitter',
#   'neighborhood',
#   'surrounding',
#   'alternate',
#   'center',
#   'city',
#   'hotel',
#   'scene',
#   'great',
#   'place',
#   'ride',
#   'share',
#   'service',
#   'center',
#   'city',
#   'depending',
#   'time',
#   'day',
#   'navy',
#   'yard',
#   'beacon',
#   'hill',
#   'walkable'],
#  ['great',
#   'location',
#   'everything',
#   'city',
#   'easy',
#   'access',
#   'orange',
#   'line',
#   'ferry'],
#  ['made', 'process', 'easy'],
#  ['great', 'host', 'clean', 'space', 'super', 'comfy', 'bed', 'highly'],
#  ['apartment',
#   'clean',
#   'everything',
#   'nice',
#   'quite',
#   'residential',
#   'area',
#   'atef',
#   'friendly',
#   'precise',
#   'strongly',
#   'recommend',
#   'choosing',
#   'apartment'],
#  ['atef',
#   'perfect',
#   'host',
#   'getting',
#   'apartment',
#   'clear',
#   'precise',
#   'unit',
#   'well',
#   'people',
#   'interested',
#   'cooking',
#   'location',
#   'convenient',
#   'one',
#   'close',
#   'monument',
#   'downtown',
#   'area',
#   'several',
#   'nice',
#   'also',
#   'available',
#   'right',
#   'outside',
#   'door',
#   'unit',
#   'less',
#   'pleasant',
#   'experience',
#   'first',
#   'time'],
#  ['studio',
#   'perfect',
#   'home',
#   'base',
#   'business',
#   'trip',
#   'boston',
#   'easy',
#   'access',
#   'orange',
#   'line',
#   'downtown',
#   'along',
#   'nearby',
#   'one',
#   'historic',
#   'made',
#   'stay',
#   'perfect',
#   'top',
#   'atef',
#   'communicative',
#   'welcoming',
#   'host',
#   'definitely',
#   'looking',
#   'stay',
#   'future'],
#  ['wonderful',
#   'place',
#   'generous',
#   'host',
#   'atef',
#   'made',
#   'stay',
#   'feel',
#   'like',
#   'home',
#   'unit',
#   'private',
#   'quite',
#   'unique',
#   'everything',
#   'could',
#   'imagine',
#   'needing',
#   'atef',
#   'generous',
#   'hospitality'],
#  ['atef',
#   'extremely',
#   'gracious',
#   'space',
#   'private',
#   'quiet',
#   'cozy',
#   'atef'],
#  ['great',
#   'location',
#   'nice',
#   'garden',
#   'walking',
#   'distance',
#   'thanks',
#   'atef',
#   'providing',
#   'everything',
#   'need',
#   'accommodating',
#   'different',
#   'sleeping',
#   'schedule',
#   'find',
#   'speedy',
#   'washing',
#   'machine',
#   'especially',
#   'useful',
#   'also',
#   'thanks',
#   'taking',
#   'make',
#   'even',
#   'comfortable'],
#  ['really', 'stay'],
#  ['great',
#   'host',
#   'perfect',
#   'location',
#   'convenient',
#   'downtown',
#   'boston',
#   'waterfront',
#   'process',
#   'seamless',
#   'atef',
#   'host',
#   'helpful'],
#  ['comfortable', 'lovely'],
#  ['atef',
#   'friendly',
#   'responsive',
#   'lots',
#   'kitchenware',
#   'available',
#   'knowledgeable',
#   'area',
#   'eager',
#   'recommend'],
#  ['would',
#   'like',
#   'say',
#   'many',
#   'thanks',
#   'stay',
#   'clean',
#   'cosy',
#   'friendly',
#   'house',
#   'family'],
#  ['great', 'stay'],
#  ['really', 'nice', 'cool', 'place'],
#  ['nice', 'place', 'stay'],
#  ['amazing', 'space', 'beautiful', 'clean', 'spacious'],
#  ['good', 'value', 'near', 'transit'],
#  ['time',
#   'home',
#   'excellent',
#   'first',
#   'strategic',
#   'location',
#   'walking',
#   'train',
#   'station',
#   'second',
#   'everything',
#   'house',
#   'third',
#   'place',
#   'comfortable',
#   'stay',
#   'short',
#   'last',
#   'important',
#   'hospitality',
#   'every',
#   'day',
#   'felt',
#   'home',
#   'every',
#   'single',
#   'detail',
#   'hemina',
#   'best',
#   'host',
#   'world',
#   'recommend',
#   'place',
#   'every',
#   'trip'],
#  ['good',
#   'place',
#   'quiet',
#   'near',
#   'subway',
#   'field',
#   'corner',
#   'easy',
#   'get',
#   'downtown',
#   'stay'],
#  ['fast',
#   'son',
#   'one',
#   'place',
#   'reserved',
#   'place',
#   'everything',
#   'excellent',
#   'would',
#   'definitely',
#   'back'],
#  ['pleasant',
#   'stay',
#   'roomy',
#   'clean',
#   'space',
#   'accommodating',
#   'hostess',
#   'easy',
#   'parking',
#   'like',
#   'would',
#   'definitely',
#   'stay'],
#  ['dont',
#   'mind',
#   'home',
#   'good',
#   'choice',
#   'really',
#   'nice',
#   'kindness',
#   'also',
#   'home',
#   'quite',
#   'sleep',
#   'well',
#   'night',
#   'thanks',
#   'coffee',
#   'nice',
#   'experience',
#   'live',
#   'house'],
#  ['fantastic', 'host', 'exactly'],
#  ['barrio'],
#  ['accommodating', 'quick', 'response'],
#  ['transport', 'elle'],
#  ['wonderful',
#   'host',
#   'considerate',
#   'attention',
#   'always',
#   'willing',
#   'help',
#   'top',
#   'delicious',
#   'comfortable',
#   'room',
#   'lovely',
#   'neighborhood',
#   'recommend'],
#  ['warm',
#   'host',
#   'lovely',
#   'front',
#   'porch',
#   'flowering',
#   'bathroom',
#   'new',
#   'spacious',
#   'clean',
#   'bedroom',
#   'good',
#   'size',
#   'clean',
#   'bedroom',
#   'open',
#   'perfect',
#   'weather',
#   'visiting',
#   'short',
#   'walk',
#   'dudley',
#   'square',
#   'bus',
#   'terminal',
#   'like',
#   'hallway',
#   'apartment',
#   'clean',
#   'bedroom',
#   'shabby',
#   'woodwork',
#   'unpainted',
#   'furniture',
#   'past',
#   'prime',
#   'small',
#   'closet',
#   'neither',
#   'bar',
#   'one',
#   'could',
#   'towel',
#   'single',
#   'hangar'],
#  ['future',
#   'days',
#   'would',
#   'list',
#   'good',
#   'bad',
#   'helpful',
#   'room',
#   'comfortable',
#   'everything',
#   'way',
#   'old',
#   'furniture',
#   'bed',
#   'closet',
#   'work',
#   'table',
#   'chair',
#   'bathroom',
#   'locked',
#   'inside',
#   'though',
#   'clean',
#   'nobody',
#   'disturbed',
#   'new',
#   'place',
#   'uncomfortable',
#   'use',
#   'bathroom',
#   'locked',
#   'first',
#   'experience',
#   'felt',
#   'many',
#   'regulation',
#   'check',
#   'time',
#   'problematic',
#   'host',
#   'previously',
#   'early',
#   'check',
#   'late',
#   'check',
#   'request',
#   'said',
#   'would',
#   'able',
#   'early',
#   'check',
#   'would',
#   'try',
#   'house',
#   'available',
#   'till',
#   'said',
#   'could',
#   'till',
#   'day',
#   'leave',
#   'day',
#   'leave',
#   'hate',
#   'last',
#   'minute',
#   'flight',
#   'spent',
#   'time',
#   'airport',
#   'difficult',
#   'carry',
#   'luggage',
#   'see',
#   'around',
#   'nearest',
#   'bus',
#   'station',
#   'dudley',
#   'square',
#   'station',
#   'used',
#   'mostly',
#   'easiest',
#   'way',
#   'location',
#   'find',
#   'safe',
#   'safety',
#   'line',
#   'pretty',
#   'thin',
#   'walk',
#   'min',
#   'station',
#   'one',
#   'day',
#   'much',
#   'noise',
#   'even',
#   'driver',
#   'told',
#   'would',
#   'use',
#   'station',
#   'night',
#   'time',
#   'house',
#   'safe',
#   'feel',
#   'safe',
#   'host',
#   'want',
#   'take',
#   'bus',
#   'station',
#   'feel',
#   'point',
#   'host',
#   'thing',
#   'stayed',
#   'lobster',
#   'dinner',
#   'host',
#   'could',
#   'meet',
#   'new',
#   'people',
#   'fun',
#   'meeting',
#   'house'],
#  ['great',
#   'welcome',
#   'plenty',
#   'visiting',
#   'pleasant',
#   'home',
#   'quiet',
#   'really',
#   'attentive',
#   'needs'],
#  ['great', 'experience', 'looking', 'forward', 'come', 'back'],
#  ['nice',
#   'location',
#   'close',
#   'medical',
#   'area',
#   'blue',
#   'bike',
#   'station',
#   'station',
#   'close',
#   'room',
#   'nice',
#   'great',
#   'host',
#   'value',
#   'money',
#   'stayed'],
#  ['stay',
#   'great',
#   'host',
# ...
#   'shower',
#   'hot',
#   'water',
#   'water',
#   'pressure'],
#  ['thank',
#   'much',
#   'absolutely',
#   'stunning',
#   'home',
#   'spotlessly',
#   'clean',
#   'wonderful',
#   'part',
#   'south',
#   'boston',
#   'communication',
#   'wonderful',
#   'would',
#   'love',
#   'stay'],
#  ['everything', 'great', 'location', 'apartment', 'thank'],
#  ['visit',
#   'home',
#   'wonderful',
#   'kept',
#   'kind',
#   'enough',
#   'allow',
#   'check',
#   'early',
#   'huge',
#   'help',
#   'coming',
#   'west',
#   'coast',
#   'tired',
#   'early',
#   'check',
#   'change',
#   'clothes',
#   'little',
#   'nap',
#   'beach',
#   'within',
#   'much',
#   'see',
#   'direction',
#   'short',
#   'walk',
#   'stop',
#   'shop',
#   'grocery',
#   'store',
#   'definitely',
#   'recommend',
#   'location'],
#  ['perfect',
#   'place',
#   'stay',
#   'marathon',
#   'comfortable',
#   'took',
#   'extra',
#   'sure',
#   'taken',
#   'care',
#   'ask',
#   'better',
#   'host',
#   'thank'],
#  ['beautiful',
#   'place',
#   'location',
#   'great',
#   'neighborhood',
#   'parking',
#   'close',
#   'public',
#   'transportation',
#   'right',
#   'outside',
#   'easy',
#   'clean',
#   'modern'],
#  ['home',
#   'beautiful',
#   'gorgeous',
#   'marble',
#   'best',
#   'kitchen',
#   'seen',
#   'bathroom',
#   'shower',
#   'top',
#   'really',
#   'comfy',
#   'sectional',
#   'end',
#   'long',
#   'day',
#   'boston',
#   'neighborhood',
#   'better',
#   'could',
#   'walk',
#   'fabulous',
#   'even',
#   'beach',
#   'provided',
#   'excellent',
#   'restaurant',
#   'probably',
#   'favorite',
#   'food',
#   'trip',
#   'super',
#   'friendly',
#   'got',
#   'connect',
#   'check',
#   'would',
#   'gladly',
#   'stay'],
#  ['beautiful',
#   'unit',
#   'within',
#   'walking',
#   'distance',
#   'beach',
#   'great',
#   'morning',
#   'walk',
#   'unit',
#   'upstairs',
#   'dont',
#   'recommend',
#   'small',
#   'may',
#   'noisy',
#   'definitely',
#   'perfect',
#   'location',
#   'couple',
#   'unit',
#   'immaculate',
#   'lovely',
#   'lot',
#   'white',
#   'dont',
#   'want',
#   'careful',
#   'eating',
#   'drinking',
#   'may',
#   'good',
#   'fit',
#   'parking',
#   'nights',
#   'park',
#   'parking',
#   'garage',
#   'away',
#   'back',
#   'overall',
#   'responsive',
#   'lovely',
#   'deal'],
#  ['looking',
#   'something',
#   'great',
#   'boston',
#   'neighborhood',
#   'hustle',
#   'bustle',
#   'close',
#   'enough',
#   'everything',
#   'great',
#   'place',
#   'apartment',
#   'comfortable',
#   'clean',
#   'nicely',
#   'decorated'],
#  ['never', 'stayed', 'fell', 'love', 'area', 'beach', 'looking', 'different'],
#  ['really', 'stay'],
#  ['recent',
#   'stay',
#   'south',
#   'boston',
#   'absolutely',
#   'impeccable',
#   'moment',
#   'pleasantly',
#   'attention',
#   'detail',
#   'thoughtful',
#   'provided',
#   'host',
#   'hospitality',
#   'truly',
#   'made',
#   'experience',
#   'standout',
#   'stay',
#   'abundance',
#   'left',
#   'extra',
#   'went',
#   'beyond',
#   'ensure',
#   'comfort',
#   'throughout',
#   'visit',
#   'little',
#   'made',
#   'huge',
#   'difference',
#   'added',
#   'welcoming',
#   'touch',
#   'entire',
#   'worth',
#   'house',
#   'book',
#   'fear',
#   'easy',
#   'follow',
#   'provided',
#   'straightforward',
#   'ensure',
#   'pleasant',
#   'stay',
#   'everyone',
#   'one',
#   'particular',
#   'rule',
#   'leave',
#   'dishwashing',
#   'machine',
#   'loaded',
#   'laundry',
#   'machine',
#   'loaded',
#   'dirty',
#   'simple',
#   'small',
#   'price',
#   'pay',
#   'overall',
#   'fantastic',
#   'experience'],
#  ['nice', 'spot', 'easy', 'downtown', 'would', 'stay'],
#  ['die',
#   'ist',
#   'die',
#   'ist',
#   'die',
#   'die',
#   'extra',
#   'war',
#   'die',
#   'ist',
#   'wir'],
#  ['home',
#   'great',
#   'peaceful',
#   'location',
#   'within',
#   'short',
#   'walk',
#   'clean',
#   'interior',
#   'spacious',
#   'real',
#   'drawback',
#   'upstairs',
#   'cool',
#   'really',
#   'well',
#   'little',
#   'warm',
#   'summer',
#   'fan',
#   'quite',
#   'noisy'],
#  ['stay',
#   'house',
#   'super',
#   'clean',
#   'comfortable',
#   'perfect',
#   'home',
#   'base',
#   'days',
#   'boston',
#   'definitely',
#   'stay'],
#  ['apartment',
#   'second',
#   'floor',
#   'clean',
#   'well',
#   'comfortable',
#   'well',
#   'responsive',
#   'helpful',
#   'good',
#   'comfortable',
#   'stay'],
#  ['beautiful',
#   'upstairs',
#   'comfortable',
#   'one',
#   'bathroom',
#   'downstairs',
#   'awesome',
#   'shower',
#   'really',
#   'stay',
#   'would',
#   'recommend',
#   'anyone',
#   'visiting',
#   'boston'],
#  ['apartment',
#   'amazing',
#   'location',
#   'lots',
#   'great',
#   'minute',
#   'walk',
#   'away',
#   'beach',
#   'minute',
#   'walk',
#   'bus',
#   'stop',
#   'boston',
#   'right',
#   'outside',
#   'house',
#   'great',
#   'comfy',
#   'sofa',
#   'made',
#   'great',
#   'place',
#   'relax',
#   'kitchen',
#   'well',
#   'everything',
#   'could',
#   'need',
#   'lovely',
#   'back',
#   'deck',
#   'breakfast',
#   'well',
#   'quickly',
#   'available',
#   'odd',
#   'question',
#   'thoroughly',
#   'recommend',
#   'place'],
#  ['location',
#   'quiet',
#   'area',
#   'nice',
#   'neighborhood',
#   'walk',
#   'beach',
#   'within',
#   'walking',
#   'distance',
#   'center',
#   'sure',
#   'public',
#   'transportation',
#   'didnt',
#   'use',
#   'apartment',
#   'clean',
#   'nicely',
#   'furnished',
#   'top',
#   'class',
#   'comfortable',
#   'would',
#   'recommend',
#   'anyone'],
#  ['fabulous',
#   'high',
#   'end',
#   'spotlessly',
#   'clean',
#   'comfortable',
#   'sofa',
#   'amazing',
#   'shower',
#   'great',
#   'close',
#   'beach'],
#  ['location', 'place', 'boston', 'brit', 'one', 'best', 'weve', 'ever'],
#  ['fantastic',
#   'host',
#   'well',
#   'organized',
#   'welcome',
#   'book',
#   'always',
#   'timely',
#   'manner',
#   'one',
#   'felt',
#   'like',
#   'really',
#   'well',
#   'highly',
#   'recommend',
#   'anyone',
#   'sure',
#   'coming',
#   'back'],
#  ['place',
#   'perfect',
#   'close',
#   'everything',
#   'quiet',
#   'friendly',
#   'neighborhood',
#   'would',
#   'definitely',
#   'stay',
#   'back',
#   'boston',
#   'thank',
#   'offering',
#   'place'],
#  ['great',
#   'time',
#   'place',
#   'rare',
#   'gem',
#   'super',
#   'nice',
#   'place',
#   'perfect'],
#  ['everything',
#   'luxury',
#   'patio',
#   'match',
#   'kitchen',
#   'felt',
#   'like',
#   'full',
#   'view',
#   'living',
#   'area',
#   'bathroom',
#   'towel',
#   'properly',
#   'two',
#   'large',
#   'wood',
#   'supporting',
#   'sink',
#   'master',
#   'bedroom',
#   'huge',
#   'rip',
#   'worn',
#   'would',
#   'mention',
#   'master',
#   'locked',
#   'use',
#   'prepared',
#   'lot',
#   'totally',
#   'fault',
#   'reading',
#   'listing',
#   'description',
#   'would',
#   'stay',
#   'give',
#   'honest',
#   'opinion'],
#  ['para'],
#  ['apartment',
#   'nice',
#   'comfortable',
#   'exactly',
#   'like',
#   'close',
#   'downtown',
#   'take',
#   'brin',
#   'summary',
#   'nice',
#   'place',
#   'comfort',
#   'shower',
#   'plus'],
#  ['great',
#   'place',
#   'everything',
#   'clean',
#   'modern',
#   'long',
#   'list',
#   'host',
#   'understand',
#   'great',
#   'communicator',
#   'quickly',
#   'highly',
#   'recommend',
#   'place',
#   'anyone',
#   'south',
#   'boston',
#   'area'],
#  ['beautiful', 'place', 'stay', 'fall', 'weekend', 'city', 'great', 'host'],
#  ['excellent',
#   'place',
#   'south',
#   'boston',
#   'right',
#   'left',
#   'car',
#   'parking',
#   'garage',
#   'used',
#   'public',
#   'transportation',
#   'get',
#   'everywhere',
#   'living',
#   'comfortable',
#   'nice'],
#  ['apartment',
#   'perfect',
#   'spot',
#   'week',
#   'bus',
#   'literally',
#   'right',
#   'outside',
#   'door',
#   'neighborhood',
#   'great',
#   'nightly',
#   'along',
#   'water',
#   'couch',
#   'super',
#   'comfortable',
#   'lovely',
#   'place',
#   'relax',
#   'day',
#   'exploring',
#   'couple',
#   'small',
#   'upon',
#   'arrival',
#   'got',
#   'back',
#   'immediately',
#   'wish',
#   'could',
#   'stayed',
#   'another',
#   'week'],
#  ['nice',
#   'house',
#   'pleasant',
#   'stay',
#   'two',
#   'aware',
#   'nearest',
#   'station',
#   'minute',
#   'walk',
#   'away',
#   'bus',
#   'service',
#   'haphazard',
#   'doesnt',
#   'seem',
#   'adhere',
#   'schedule',
#   'week',
#   'really',
#   'good',
#   'value'],
#  ['wonderful',
#   'time',
#   'cozy',
#   'well',
#   'furnished',
#   'house',
#   'boston',
#   'close',
#   'enough',
#   'walk',
#   'conference',
#   'convention',
#   'center',
#   'lots',
#   'mass',
#   'transit',
#   'well',
#   'apartment',
#   'wonderful',
#   'respite',
#   'long',
#   'day'],
#  ['great',
#   'quiet',
#   'area',
#   'quick',
#   'downtown',
#   'boston',
#   'short',
#   'walk',
#   'away'],
#  ['great',
#   'time',
#   'home',
#   'easy',
#   'find',
#   'clear',
#   'like',
#   'group',
#   'catching',
#   'large',
#   'sofa',
#   'good',
#   'use',
#   'space',
#   'would',
#   'stay'],
#  ['family',
#   'stay',
#   'lovely',
#   'home',
#   'south',
#   'boston',
#   'responsive',
#   'host',
#   'home',
#   'long',
#   'weekend'],
#  ['friendly',
#   'responsive',
#   'place',
#   'wasnt',
#   'fit',
#   'really',
#   'hearing',
#   'feedback',
#   'flexible',
#   'location',
#   'great',
#   'price',
#   'excellent',
#   'expensive',
#   'area',
#   'probably',
#   'perfect',
#   'fit',
#   'fuss',
#   'budget',
#   'traveler',
#   'fussy',
#   'find',
#   'spot',
#   'great',
#   'responsive',
#   'host'],
#  ['old', 'building', 'good', 'space', 'value', 'great', 'relaxed', 'body'],
#  ['conference',
#   'home',
#   'short',
#   'min',
#   'drive',
#   'min',
#   'walk',
#   'boston',
#   'convention',
#   'center'],
#  ['really', 'helpful', 'place', 'amazing', 'family', 'stay'],
#  ['great', 'time', 'south', 'boston'],
#  ['came',
#   'boston',
#   'day',
#   'event',
#   'boston',
#   'convention',
#   'exhibition',
#   'center',
#   'place',
#   'ideally',
#   'situated',
#   'close',
#   'enough',
#   'walk',
#   'min',
#   'far',
#   'enough',
#   'quiet',
#   'still',
#   'great',
#   'selection',
#   'south',
#   'great',
#   'host',
#   'took',
#   'care',
#   'make',
#   'feel',
#   'place',
#   'old',
#   'clean',
#   'business',
#   'trip',
#   'small',
#   'office',
#   'good',
#   'price',
#   'going',
#   'meeting',
#   'seaport',
#   'highly',
#   'recommend',
#   'place'],
#  ['stayed',
#   'place',
#   'visiting',
#   'conference',
#   'perfect',
#   'fit',
#   'boston',
#   'conference',
#   'center',
#   'within',
#   'min',
#   'walking',
#   'distance',
#   'apartment',
#   'bigger',
#   'second',
#   'floor',
#   'kitchen',
#   'living',
#   'room',
#   'downstairs',
#   'unfortunately',
#   'time',
#   'cook',
#   'would',
#   'definitely',
#   'possible',
#   'communication',
#   'easy',
#   'kind',
#   'time',
#   'flexible',
#   'thanks'],
#  ['great',
#   'value',
#   'stay',
#   'safe',
#   'clean',
#   'place',
#   'stay',
#   'comfy',
#   'washing',
#   'works',
#   'great',
#   'inside',
#   'house',
#   'pretty',
#   'quiet',
#   'fully',
#   'gem',
#   'traveling',
#   'dogs',
#   'lots',
#   'food',
#   'nearby',
#   'walk',
#   'within',
#   'breakfast',
#   'lunch',
#   'also',
#   'convenience',
#   'store',
#   'literally',
#   'around',
#   'corner',
#   'manage',
#   'given',
#   'older',
#   'home',
#   'great',
#   'location',
#   'affordable',
#   'price',
#   'point',
#   'would',
#   'definitely',
#   'stay',
#   'explore',
#   'city'],
#  ['family',
#   'town',
#   'vacation',
#   'location',
#   'easy',
#   'walking',
#   'around',
#   'south',
#   'boston',
#   'nearby',
#   'home',
#   'exactly',
#   'thought',
#   'would',
#   'hate',
#   'door',
#   'ended',
#   'loving',
#   'people',
#   'aware',
#   'typical',
#   'area',
#   'upstairs',
#   'steep',
#   'narrow',
#   'going',
#   'bathroom',
#   'need',
#   'use',
#   'musty',
#   'smell',
#   'basement',
#   'keeping',
#   'door',
#   'closed',
#   'made',
#   'fine',
#   'went',
#   'get',
#   'outdoor',
#   'space',
#   'space',
#   'incredible',
#   'didnt',
#   'use',
#   'grass',
#   'long',
#   'know',
#   'back',
#   'back',
#   'making',
#   'difficult',
#   'kitchen',
#   'home',
#   'except',
#   'toaster',
#   'truly',
#   'boston',
#   'eat',
#   'found',
#   'parking',
#   'easiest',
#   'affordable',
#   'city',
#   'outdoor',
#   'lot',
#   'street',
#   'mile',
#   'away',
#   'extremely',
#   'responsive',
#   'helpful'],
#  ['facile', 'boston', 'ville', 'bon', 'boston'],
#  ['great', 'place', 'stay', 'boston', 'great', 'sleep', 'quiet', 'night'],
#  ['place',
#   'iron',
#   'board',
#   'got',
#   'back',
#   'first',
#   'day',
#   'conference',
#   'trouble',
#   'nest',
#   'logged',
#   'fixed',
#   'hot',
#   'days',
#   'upstairs',
#   'bathroom',
#   'downstairs',
#   'need',
#   'close',
#   'convenience',
#   'market',
#   'right',
#   'around',
#   'corner',
#   'lots',
#   'defined',
#   'older',
#   'home',
#   'safe'],
#  ['great',
#   'option',
#   'wedding',
#   'south',
#   'boston',
#   'home',
#   'could',
#   'use',
#   'older',
#   'home',
#   'boston',
#   'theres',
#   'expectation',
#   'older',
#   'felt',
#   'run'],
#  ['basic',
#   'older',
#   'outdated',
#   'space',
#   'little',
#   'unlevel',
#   'clean',
#   'comfortable',
#   'looking',
#   'want',
#   'clean',
#   'space',
#   'also',
#   'dog',
#   'friendly',
#   'walking',
#   'distance',
#   'many',
#   'looking',
#   'responsive',
#   'left',
#   'locate',
#   'free',
#   'parking',
#   'old',
#   'colony',
#   'pay',
#   'attention',
#   'street',
#   'cleaning',
#   'stay',
#   'next',
#   'time',
#   'boston'],
#  ['everything',
#   'worked',
#   'perfectly',
#   'parking',
#   'whole',
#   'area',
#   'need',
#   'permit',
#   'resident',
#   'thing',
#   'made',
#   'trip',
#   'difficult',
#   'lot',
#   'felt',
#   'safe',
#   'area',
#   'boston',
#   'actually'],
#  ['perfect', 'affordable', 'option', 'conference'],
#  ['place',
#   'great',
#   'think',
#   'price',
#   'could',
#   'mildly',
#   'better',
#   'relative',
#   'similar',
#   'also',
#   'far',
#   'average',
#   'response',
#   'times',
#   'helpfulness'],
#  ['great',
#   'place',
#   'downtown',
#   'boston',
#   'found',
#   'really',
#   'great',
#   'place',
#   'explore',
#   'city',
#   'quiet',
#   'easy',
#   'access',
#   'coast',
#   'foot'],
#  ['great',
#   'place',
#   'stay',
#   'especially',
#   'near',
#   'convention',
#   'center',
#   'extremely',
#   'responsive',
#   'easy',
#   'work',
#   'two',
#   'aware',
#   'car',
#   'parking',
#   'bit',
#   'headache',
#   'need',
#   'find',
#   'street',
#   'parking',
#   'slant',
#   'downward',
#   'sleeping',
#   'slant',
#   'really',
#   'stay',
#   'definitely',
#   'recommend'],
#  ['beautiful',
#   'house',
#   'great',
#   'location',
#   'extremely',
#   'helpful',
#   'communicative',
#   'definitely',
#   'stay',
#   'next',
#   'time',
#   'visit',
#   'boston'],
#  ['close', 'great', 'mention', 'train'],
#  ['nice', 'stay'],
#  ['great', 'stay', 'definitely', 'recommend'],
#  ['excellent',
#   'host',
#   'home',
#   'worked',
#   'perfectly',
#   'trip',
#   'boston',
#   'clean',
#   'open',
#   'space',
#   'lot',
#   'perfect',
#   'big',
#   'group',
#   'location',
#   'ideal',
#   'looking',
#   'explore',
#   'city',
#   'surrounding',
#   'bit'],
#  ['nice', 'place', 'cozy'],
#  ['place',
#   'great',
#   'place',
#   'stay',
#   'town',
#   'boston',
#   'marathon',
#   'perfect',
#   'group',
#   'size',
#   'people',
#   'king',
#   'bed',
#   'upstairs',
#   'one',
#   'double',
#   'bed',
#   'bedroom',
#   'one',
#   'comfortable',
#   'couch',
#   'downstairs',
#   'unit',
#   'clean',
#   'great',
#   'full',
#   'recently',
#   'neighborhood',
#   'little',
#   'gritty',
#   'quiet',
#   'house',
#   'right',
#   'next',
#   'police',
#   'station',
#   'never',
#   'felt',
#   'unsafe',
#   'close',
#   'red',
#   'line',
#   'easy',
#   'get',
#   'downtown',
#   'anywhere',
#   'else',
#   'spacious',
#   'phenomenal',
#   'value',
#   'entry',
#   'made',
#   'easy',
#   'check',
#   'come',
#   'accommodating',
#   'drop',
#   'ahead',
#   'ever',
#   'back',
#   'boston',
#   'group',
#   'would',
#   'definitely',
#   'stay'],
#  ['amazing',
#   'experience',
#   'host',
#   'warm',
#   'professional',
#   'place',
#   'superb',
#   'great',
#   'kitchen',
#   'coffee',
#   'beautiful',
#   'location',
#   'also',
#   'great',
#   'conveniently',
#   'close',
#   'amazing',
#   'value',
#   'would',
#   'definitely',
#   'recommend'],
#  ['clear', 'get', 'place', 'also', 'included', 'around', 'dine', 'great'],
#  ['family',
#   'great',
#   'vacation',
#   'hemina',
#   'home',
#   'cozy',
#   'nice',
#   'decorated',
#   'apartment',
#   'anything',
#   'need',
#   'location',
#   'five',
#   'red',
#   'line',
#   'station',
#   'grocery',
#   'store',
#   'lot',
#   'nearby',
#   'also',
#   'center',
#   'bodhisattva',
#   'garden',
#   'front',
#   'home',
#   'boston',
#   'police',
#   'station',
#   'behind',
#   'home',
#   'make',
#   'feel',
#   'peace',
#   'safe',
#   'home',
#   'little',
#   'pretty',
#   'garden',
#   'fruitful',
#   'apple',
#   'tree',
#   'stay',
#   'enjoy',
#   'stay',
#   'lots',
#   'thanks',
#   'host',
#   'hemina'],
#  ['best',
#   'part',
#   'location',
#   'proximity',
#   'corner',
#   'station',
#   'great',
#   'able',
#   'access',
#   'public',
#   'transit',
#   'easily',
#   'home',
#   'also',
#   'clean',
#   'host',
#   'provided',
#   'good',
#   'important',
#   'note',
#   'home',
#   'right',
#   'next',
#   'police',
#   'station',
#   'expect',
#   'hear',
#   'relatively',
#   'frequently',
#   'day',
#   'night'],
#  ['good'],
#  ['place',
#   'comfortable',
#   'well',
#   'four',
#   'people',
#   'close',
#   'subway',
#   'stop',
#   'number',
#   'good',
#   'parking',
#   'one',
#   'vehicle',
#   'site',
#   'let',
#   'use',
#   'parking',
#   'street',
#   'available',
#   'hard',
#   'find',
#   'kitchen',
#   'well',
#   'coffee',
#   'breakfast'],
#  ...]

# %%
data1
# Out:
#                  listing_id review_date  reviewer_id  \
# 14                     3781  2019-02-22     83031353
# 15                     3781  2019-12-21      3918963
# 16                     3781  2020-09-03    344701185
# 17                     3781  2020-12-20    348888007
# 18                     3781  2021-02-26    345613836
# ...                     ...         ...          ...
# 182477  1039150219616773193  2023-12-13    381198215
# 182478  1040527526059629043  2023-12-08      9723289
# 182479  1040634799097914803  2023-12-15    494876133
# 182480  1040634799097914803  2023-12-18     94199776
# 182481  1046563598019556549  2023-12-16    336213171
#
#                                                  comments  \
# 14      My partner and I stayed at Frank's apartment f...
# 15      I liked very much this apartment rented by Fra...
# 16      I stayed at Frank's apartment for three months...
# 17      Wonderful 1 bedroom with a great location! The...
# 18      Great place - amazing location.   Highly recom...
# ...                                                   ...
# 182477  A wonderful location to walk around the North ...
# 182478                   Great deal and responsive hosts!
# 182479  Our stay at Diego’s place was great!<br/>The a...
# 182480  Good place; solid bedrooms/bathrooms; nice to ...
# 182481          Great host great home and amazing service
#
#        neighbourhood_cleansed  price   latitude  longitude        room_type  \
# 14                East Boston  125.0  42.364130 -71.029910  Entire home/apt
# 15                East Boston  125.0  42.364130 -71.029910  Entire home/apt
# 16                East Boston  125.0  42.364130 -71.029910  Entire home/apt
# 17                East Boston  125.0  42.364130 -71.029910  Entire home/apt
# 18                East Boston  125.0  42.364130 -71.029910  Entire home/apt
# ...                       ...    ...        ...        ...              ...
# 182477              North End  110.0  42.365322 -71.055627  Entire home/apt
# 182478            East Boston  140.0  42.381106 -71.026179  Entire home/apt
# 182479                Roxbury  144.0  42.325558 -71.073339  Entire home/apt
# 182480                Roxbury  144.0  42.325558 -71.073339  Entire home/apt
# 182481             Dorchester   83.0  42.285236 -71.069907  Entire home/apt
#
#         number_of_reviews  review_scores_rating
# 14                     24                  4.96
# 15                     24                  4.96
# 16                     24                  4.96
# 17                     24                  4.96
# 18                     24                  4.96
# ...                   ...                   ...
# 182477                  1                  5.00
# 182478                  1                  5.00
# 182479                  2                  4.50
# 182480                  2                  4.50
# 182481                  1                  5.00
#
# [136382 rows x 11 columns]

# %% [markdown]
# ### Alpha and Beta in LDA

# %%
from gensim import corpora, models
from gensim.models import CoherenceModel

comments = data['comments'].tolist()

# Creating a dictionary
dictionary = corpora.Dictionary(comments)

# Corpus needed for Topic Modeling
corpus = [dictionary.doc2bow(text) for text in comments]

# Print the words in topics with their weights
def print_topic_words(model, num_top_words):
    for topic_id in range(model.num_topics):
        words = model.show_topic(topic_id, topn=num_top_words)
        topic_words = ", ".join([word for word, _ in words])
        print(f"Topic {topic_id}: {topic_words}")

# %%
# model 1: LDA with symmetric alpha
lda_model1 = models.LdaModel(corpus, num_topics=15, id2word=dictionary, passes=1, alpha='symmetric')
print_topic_words(lda_model1, 10)
# Out:
# Topic 0: room, kitchen, bathroom, space, nice, house, well, living, two, hotel
# Topic 1: boston, stay, definitely, place, would, time, back, perfect, come, next
# Topic 2: quiet, neighborhood, clean, stay, comfortable, parking, safe, well, spacious, apartment
# Topic 3: night, room, shower, water, bed, could, one, noise, door, day
# Topic 4: home, like, stay, host, felt, made, everything, place, feel, sure
# Topic 5: apartment, super, amazing, cute, location, clean, boston, place, everything, beautiful
# Topic 6: close, boston, place, downtown, public, great, stay, easy, airport, city
# Topic 7: thank, property, min, pleasant, die, accommodation, question, ist, met, much
# Topic 8: stay, recommend, great, would, host, place, responsive, clean, location, highly
# Topic 9: great, location, place, stay, good, nice, clean, everything, really, comfortable
# Topic 10: parking, would, apartment, place, good, bit, stay, floor, one, unit
# Topic 11: boston, bien, pour, nous, description, visiting, surrounding, college, son, stays
# Topic 12: easy, check, great, location, access, clean, unit, apartment, communication, find
# Topic 13: best, staff, friendly, stayed, one, breakfast, ever, fun, coffee, comfortable
# Topic 14: walking, location, distance, great, boston, walk, within, apartment, right, end

# %%
# evaluate the models using Coherence Score
coherence_model_lda1 = CoherenceModel(model=lda_model1, texts=comments, dictionary=dictionary, coherence='c_v')
coherence_lda1 = coherence_model_lda1.get_coherence()

print("\nCoherence Score for Model 1:", coherence_lda1)
# Out:
# Coherence Score for Model 1: 0.5285290164047015

# %%
# model 2: LDA with asymmetric alpha and fixed eta
lda_model2 = models.LdaModel(corpus, num_topics=15, id2word=dictionary, passes=1, alpha='asymmetric', eta=0.5)
print_topic_words(lda_model2, 10)
# Out:
# Topic 0: place, nice, great, clean, easy, location, good, stay, close, really
# Topic 1: would, host, check, place, stay, hotel, one, day, get, time
# Topic 2: parking, street, space, great, kitchen, area, room, clean, nice, comfortable
# Topic 3: great, stay, place, location, recommend, would, host, clean, highly, definitely
# Topic 4: home, like, felt, stay, made, place, feel, sure, everything, amazing
# Topic 5: walk, boston, station, minute, train, close, line, short, downtown, away
# Topic 6: perfect, boston, location, place, back, great, stay, city, apartment, everything
# Topic 7: time, boston, room, next, best, stay, visit, ever, stayed, one
# Topic 8: house, decorated, lovely, beautiful, fun, beautifully, friendly, lee, neighborhood, space
# Topic 9: coffee, kitchen, water, breakfast, provided, morning, even, nice, also, use
# Topic 10: walking, distance, within, store, many, grocery, service, street, across, food
# Topic 11: room, bathroom, noise, floor, night, bed, location, apartment, building, shower
# Topic 12: staff, dan, para, con, hotel, excelente, fixed, wine, solo, boston
# Topic 13: stay, clean, responsive, place, would, host, comfortable, definitely, wonderful, thank
# Topic 14: bien, pour, nous, hill, boston, beacon, district, tout, gym, super

# %%
# evaluate the models using Coherence Score
coherence_model_lda2 = CoherenceModel(model=lda_model2, texts=comments, dictionary=dictionary, coherence='c_v')
coherence_lda2 = coherence_model_lda2.get_coherence()

print("Coherence Score for Model 2:", coherence_lda2)
# Out:
# Coherence Score for Model 2: 0.5703253598886822

# %%
# model 3: LDA with auto alpha and eta
lda_model3 = models.LdaModel(corpus, num_topics=15, id2word=dictionary, passes=1, alpha='auto', eta='auto')
print_topic_words(lda_model3, 10)
# Out:
# Topic 0: walking, distance, within, end, location, apartment, north, boston, many, great
# Topic 1: room, bathroom, bed, kitchen, shower, nice, water, small, floor, comfortable
# Topic 2: boston, perfect, spot, great, location, time, place, stay, weekend, trip
# Topic 3: boston, close, easy, public, access, downtown, location, walkable, transportation, great
# Topic 4: apartment, need, kitchen, large, group, space, well, everything, hill, big
# Topic 5: hotel, staff, host, room, issue, listing, never, care, working, booking
# Topic 6: check, door, early, late, got, get, next, front, day, flight
# Topic 7: back, beautiful, come, apartment, neighborhood, well, quiet, lovely, comfortable, bay
# Topic 8: walk, easy, parking, station, close, get, minute, train, around, boston
# Topic 9: home, stay, boston, made, felt, like, host, sure, feel, time
# Topic 10: night, noise, apartment, bit, one, street, unit, parking, building, little
# Topic 11: bien, boston, pour, nous, para, con, die, excelente, apt, super
# Topic 12: great, location, apartment, good, communication, clean, excellent, easy, host, check
# Topic 13: best, thank, one, worth, ever, stayed, better, could, much, price
# Topic 14: place, stay, great, clean, would, nice, location, host, definitely, recommend

# %%
# evaluate the models using Coherence Score
coherence_model_lda3 = CoherenceModel(model=lda_model3, texts=comments, dictionary=dictionary, coherence='c_v')
coherence_lda3 = coherence_model_lda3.get_coherence()

print("Coherence Score for Model 3:", coherence_lda3)
# Out:
# Coherence Score for Model 3: 0.6040438040429527
